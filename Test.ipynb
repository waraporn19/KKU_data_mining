# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-blob==2.1.0
# Out:
# ...
#      |████████████████████████████████| 92kB 4.1MB/s
# ...
#      |████████████████████████████████| 51kB 5.1MB/s
# ...
#      |████████████████████████████████| 3.2MB 9.2MB/s
# ...

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
 blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %%
img_9015 = '72F8A10D-3532-4F4B-8122-8BC3FFB201AE.png'
img_9013 = 'D2BAF78A-7431-4AAA-98FE-719E03EA189B.png'
img_9024 = '3F758FC2-2357-4BAF-AA40-E7E1F3B8832C.png'
img_9034 = '8D9959BD-31DD-4162-B86C-E8A0C0B197EF.png'
img_9044 = '7234B1DA-C86D-4957-85F7-724D9BE7FE30.png'

# %%
full_path_to_file2 = os.path.join(img_9015) #รูปที่ 1 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9013) #รูปที่ 1 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9024) #รูปที่ 1
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9034) #รูปที่ 1 9034
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9044) #รูปที่ 1 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %%
#รูปที่ 1   ก่อนปรับขนาดภาพ
imgC2 = cv2.imread(img_9015)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC2 = cv2.cvtColor(imgC2, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC2)#โชว์รูป

# %%
#รูปที่ 1   ก่อนปรับขนาดภาพ
imgC21 = cv2.imread(img_9013)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC21 = cv2.cvtColor(imgC21, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC21)#โชว์รูป

# %%
#รูปที่ 1   ก่อนปรับขนาดภาพ
imgC3 = cv2.imread(img_9024)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC3 = cv2.cvtColor(imgC3, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC3)#โชว์รูป

# %%
#รูปที่ 1   ก่อนปรับขนาดภาพ
imgC4 = cv2.imread(img_9034)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC4 = cv2.cvtColor(imgC4, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC4)#โชว์รูป

# %%
#รูปที่ 1   ก่อนปรับขนาดภาพ
imgD2 = cv2.imread(img_9044)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgD2 = cv2.cvtColor(imgD2 , cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgD2)#โชว์รูป

# %%
for i in range(RGB_imgC2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 480 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 400 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 400 colum
                if 240<=i<=260 and 220<=j<=245:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 240-260 ค่า j  ที่เข้ามาอยู่ระหว่าง 220-245
                    print(RGB_imgC2[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# [37 41 40]
# [43 47 46]
# [42 46 45]
# [43 47 46]
# [29 33 32]
# [39 43 42]
# [38 42 41]
# [39 43 42]
# [38 42 41]
# [39 43 42]
# [34 38 37]
# [40 44 43]
# [30 34 33]
# [34 38 37]
# [40 44 43]
# [40 44 43]
# [37 41 40]
# [39 43 42]
# [44 48 47]
# [42 46 45]
# [33 37 36]
# [36 40 39]
# [42 46 45]
# [39 43 42]
# [40 44 43]
# [43 47 46]
# [40 44 43]
# [38 42 41]
# [36 40 39]
# [39 43 42]
# [38 42 41]
# [38 42 41]
# [38 42 41]
# [39 43 42]
# [41 45 44]
# [36 40 39]
# [34 38 37]
# [38 42 41]
# [37 41 40]
# [41 45 44]
# [38 42 41]
# [38 42 41]
# [43 47 46]
# [39 43 42]
# [35 39 38]
# [40 44 43]
# [38 42 41]
# [34 38 37]
# [41 45 44]
# [35 39 38]
# [34 38 37]
# [41 45 44]
# [30 34 33]
# [35 39 38]
# [47 51 50]
# [39 43 42]
# [36 40 39]
# [33 37 36]
# [36 40 39]
# [33 37 36]
# [40 44 43]
# [40 44 43]
# [43 47 46]
# [40 44 43]
# [40 44 43]
# [36 40 39]
# [39 43 42]
# [41 45 44]
# [37 41 40]
# [37 41 40]
# [40 44 43]
# [40 44 43]
# [36 40 39]
# [35 39 38]
# [41 45 44]
# [40 44 43]
# ...

# %%
for i in range(RGB_imgC21.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 480 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC21.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 400 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 400 colum
                if 240<=i<=260 and 220<=j<=245:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 240-260 ค่า j  ที่เข้ามาอยู่ระหว่าง 220-245
                    print(RGB_imgC21[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# [35 39 38]
# [35 39 38]
# [38 42 41]
# [33 37 36]
# [31 35 34]
# [37 41 40]
# [35 39 38]
# [31 35 34]
# [38 42 41]
# [40 44 43]
# [32 36 35]
# [32 36 35]
# [38 42 41]
# [40 44 43]
# [38 42 41]
# [32 36 35]
# [41 45 44]
# [24 28 27]
# [36 40 39]
# [45 49 48]
# [40 45 41]
# [40 45 41]
# [36 40 39]
# [37 41 40]
# [43 47 46]
# [42 46 45]
# [32 36 35]
# [33 37 36]
# [41 45 44]
# [38 42 41]
# [36 40 39]
# [31 35 34]
# [40 44 43]
# [44 48 47]
# [36 40 39]
# [37 41 40]
# [38 42 41]
# [32 36 35]
# [41 45 44]
# [39 43 42]
# [38 42 41]
# [47 51 50]
# [38 42 41]
# [29 33 32]
# [30 34 33]
# [46 50 49]
# [41 46 42]
# [40 45 41]
# [36 40 39]
# [32 36 35]
# [42 46 45]
# [33 37 36]
# [37 41 40]
# [36 40 39]
# [36 40 39]
# [41 45 44]
# [38 42 41]
# [41 45 44]
# [40 44 43]
# [38 42 41]
# [41 45 44]
# [35 39 38]
# [29 33 32]
# [38 42 41]
# [44 48 47]
# [37 41 40]
# [41 45 44]
# [48 52 51]
# [33 37 36]
# [27 31 30]
# [35 39 38]
# [37 41 40]
# [35 40 36]
# [39 44 40]
# [38 42 41]
# [35 39 38]
# ...

# %%
for i in range(RGB_imgC3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 480 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 400 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 400 colum
                if 240<=i<=260 and 220<=j<=245:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 240-260 ค่า j  ที่เข้ามาอยู่ระหว่าง 220-245
                    print(RGB_imgC3[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# [31 36 32]
# [40 45 41]
# [46 51 47]
# [43 48 44]
# [42 47 43]
# [38 43 39]
# [44 49 45]
# [48 53 49]
# [36 41 37]
# [36 41 37]
# [35 40 36]
# [38 43 39]
# [46 51 47]
# [49 54 50]
# [46 51 47]
# [49 54 50]
# [44 49 45]
# [37 42 38]
# [36 41 37]
# [43 48 44]
# [32 37 33]
# [47 52 48]
# [33 38 34]
# [33 38 34]
# [40 45 41]
# [38 43 39]
# [36 41 37]
# [33 38 34]
# [30 35 31]
# [39 44 40]
# [45 50 46]
# [40 45 41]
# [42 47 43]
# [46 51 47]
# [40 45 41]
# [40 45 41]
# [35 40 36]
# [36 41 37]
# [45 50 46]
# [43 48 44]
# [33 38 34]
# [40 45 41]
# [48 53 49]
# [34 39 35]
# [41 46 42]
# [35 40 36]
# [37 42 38]
# [43 48 44]
# [46 51 47]
# [44 49 45]
# [41 46 42]
# [46 51 47]
# [38 43 39]
# [42 47 43]
# [37 42 38]
# [44 49 45]
# [45 50 46]
# [43 48 44]
# [37 42 38]
# [36 41 37]
# [41 46 42]
# [45 50 46]
# [36 41 37]
# [32 37 33]
# [41 46 42]
# [50 55 51]
# [33 38 34]
# [39 44 40]
# [34 39 35]
# [34 39 35]
# [44 49 45]
# [40 45 41]
# [45 50 46]
# [37 42 38]
# [37 42 38]
# [36 41 37]
# ...

# %%
for i in range(RGB_imgC4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 480 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 400 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 400 colum
                if 240<=i<=260 and 220<=j<=245:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 240-260 ค่า j  ที่เข้ามาอยู่ระหว่าง 220-245
                    print(RGB_imgC4[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# [41 45 44]
# [37 41 40]
# [41 45 44]
# [39 43 42]
# [40 44 43]
# [42 46 45]
# [33 37 36]
# [29 33 32]
# [32 36 35]
# [36 40 39]
# [44 48 47]
# [49 53 52]
# [42 46 45]
# [36 40 39]
# [34 38 37]
# [42 46 45]
# [32 36 35]
# [43 47 46]
# [46 50 49]
# [44 48 47]
# [48 52 51]
# [50 54 53]
# [25 29 28]
# [27 31 30]
# [42 46 45]
# [39 43 42]
# [35 39 38]
# [37 41 40]
# [37 41 40]
# [42 46 45]
# [44 48 47]
# [43 47 46]
# [41 45 44]
# [39 43 42]
# [33 37 36]
# [31 35 34]
# [37 41 40]
# [43 47 46]
# [45 49 48]
# [41 45 44]
# [35 39 38]
# [39 43 42]
# [32 36 35]
# [40 44 43]
# [47 51 50]
# [45 49 48]
# [44 48 47]
# [46 50 49]
# [38 42 41]
# [29 33 32]
# [33 37 36]
# [40 44 43]
# [46 50 49]
# [40 44 43]
# [34 38 37]
# [37 41 40]
# [40 44 43]
# [35 39 38]
# [39 43 42]
# [42 46 45]
# [39 43 42]
# [37 41 40]
# [39 43 42]
# [42 46 45]
# [43 47 46]
# [45 49 48]
# [42 46 45]
# [43 47 46]
# [39 43 42]
# [39 43 42]
# [47 51 50]
# [42 46 45]
# [31 35 34]
# [48 52 51]
# [49 53 52]
# [44 48 47]
# ...

# %%
for i in range(RGB_imgD2 .shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 480 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgD2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 400 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 400 colum
                if 240<=i<=260 and 220<=j<=245:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 240-260 ค่า j  ที่เข้ามาอยู่ระหว่าง 220-245
                    print(RGB_imgD2 [i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# [36 41 37]
# [28 33 29]
# [28 33 29]
# [34 39 35]
# [28 33 29]
# [28 33 29]
# [33 38 34]
# [30 35 31]
# [31 36 32]
# [38 43 39]
# [35 40 36]
# [27 32 28]
# [37 42 38]
# [40 45 41]
# [31 36 32]
# [27 32 28]
# [36 41 37]
# [36 41 37]
# [31 36 32]
# [34 39 35]
# [24 29 25]
# [32 37 33]
# [26 31 27]
# [30 35 31]
# [30 35 31]
# [29 34 30]
# [30 35 31]
# [29 34 30]
# [34 39 35]
# [29 34 30]
# [30 35 31]
# [26 31 27]
# [27 32 28]
# [34 39 35]
# [40 45 41]
# [36 41 37]
# [30 35 31]
# [34 39 35]
# [30 35 31]
# [32 37 33]
# [34 39 35]
# [27 32 28]
# [28 33 29]
# [34 39 35]
# [32 37 33]
# [31 36 32]
# [35 40 36]
# [34 39 35]
# [32 37 33]
# [29 34 30]
# [28 33 29]
# [34 39 35]
# [29 34 30]
# [31 36 32]
# [28 33 29]
# [34 39 35]
# [31 36 32]
# [35 40 36]
# [27 32 28]
# [29 34 30]
# [40 45 41]
# [32 37 33]
# [25 30 26]
# [34 39 35]
# [33 38 34]
# [35 40 36]
# [28 33 29]
# [31 36 32]
# [35 40 36]
# [29 34 30]
# [31 36 32]
# [34 39 35]
# [32 37 33]
# [30 35 31]
# [30 35 31]
# [30 35 31]
# ...

# %%
resized_imageC2 = cv2.resize(RGB_imgC2,(480,400))#กำหนดขนาดของรูป (x,y)
imgC2= cv2.rectangle(resized_imageC2,(220,260),(250,240),(255,0,0),1) #วาดสี่เหลี่ยม
plt.imshow(resized_imageC2)

# %%
resized_imageC21 = cv2.resize(RGB_imgC21,(480,400))#กำหนดขนาดของรูป (x,y)
imgC21= cv2.rectangle(resized_imageC21,(220,260),(250,240),(255,0,0),1) #วาดสี่เหลี่ยม
plt.imshow(resized_imageC21)

# %%
resized_imageC3 = cv2.resize(RGB_imgC3,(480,400))#กำหนดขนาดของรูป (x,y)
imgC3= cv2.rectangle(resized_imageC3,(220,260),(250,240),(255,0,0),1) #วาดสี่เหลี่ยม
plt.imshow(resized_imageC3)

# %%
resized_imageC4 = cv2.resize(RGB_imgC4,(480,400))#กำหนดขนาดของรูป (x,y)
imgC4= cv2.rectangle(resized_imageC4,(220,260),(250,240),(255,0,0),1) #วาดสี่เหลี่ยม
plt.imshow(resized_imageC4)

# %%
resized_imageD2 = cv2.resize(RGB_imgD2,(480,400))#กำหนดขนาดของรูป (x,y)
imgD2= cv2.rectangle(resized_imageD2,(220,260),(250,240),(255,0,0),1) #วาดสี่เหลี่ยม
plt.imshow(resized_imageD2)
