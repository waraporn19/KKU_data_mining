# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Project_AnimalFeed_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เริ่มแรกมีการหาข้อมูลจาก เว็ปไซส์ data.go.th
#
# ###ทำให้เราได้ข้อมูล การนำเข้าอาหารสัตว์ และ การส่งออกอาหารสัตว์ ในปี 2015 มา
#
# ข้อมูลการนำเข้าอาหารสัตว์ : https://data.go.th/dataset/item_de26c80b-0571-4721-8a82-aeed70919906
#
# ข้อมูลการส่งออกอาหารสัตว์ : https://data.go.th/dataset/item_94a0b576-c3ee-45ec-8de6-d07b55921571

# %% [markdown]
# ##วัตถุประสงค์ *ตรวจหน่อย
#
# เพื่อศึกษาความสัมพันธ์ของปริมาณการนำเข้าอาหารสัตว์ A แล้วจะทำให้มีปริมาณส่งออกอาหารสัตว์ B  จะมีโอกาสหรือความน่าจะเป็นเกิดขึ้นหรือไม่
#
# เพื่อศึกษาเป็นความรู้หรือดูความสัมพันธ์ที่ได้จากกระบวนการนี้สามารถนำไปใช้คาดเดาได้ว่าควรนำเข้าอาหารสัตว์และส่งออกอาหารสัตว์เพิ่มขึ้นให้กับแต่ละประเทศเท่าใด ในปีค.ศ. 2015

# %%
from google.colab import drive 
drive.mount('/content/drive')

# %%
path = '/content/drive/My Drive/Project_Mining' #ให้ข้อมูลที่อยู่ใน Drive แทนด้วยชื่อ path

# %%
## เรียกใช้ฟังก์ชั่น os และ pandas as pd
import os
import pandas as pd

# %%
from pandas.api.types import CategoricalDtype

# %%
Import= os.path.join(path,'Import_nw4.csv')  #สร้างที่อยู่โดยใช้ os.path.join
Export= os.path.join(path,'Ex_animalfeed_tun3.csv')

# %%
Import_df = pd.read_csv(Import) # อ่านข้อมูลที่อยู่ในไฟล์ Import_nw4 โดยให้อยู่ในชื่อ Import_df
Import_df.head() #เรียกดูตารางในไฟล์ Import

# %% [markdown]
# ชื่อหัวคอลั่ม Import การนำเข้า
#
# Country = ประเทศที่นำเข้า
#
# Import_of_main_raw_materials = นำเข้าวัตถุดิบหลัก
#
# Import_the_mixed = นำเข้าวัตถุที่ผสมแล้ว
#
# Imported_dairy_products = นำเข้าผลิตภัณฑ์นม
#
# Import_of_pet_supplement = นำเข้าอาหารเสริมสำหรับสัตว์
#
# Import_other_animal_feed = นำเข้าวัตถุดิบอื่นๆ

# %%
Export_df = pd.read_csv(Export) 
Export_df.head() #เรียกตารางมาดู

# %% [markdown]
# ชื่อหัวคอลั่ม Export การส่งออก
#
# Country = ประเทศที่ส่งออก
#
# Export_of_fishmeal = ส่งออกปลาป่น
#
# Export_of_dogcat_food = ส่งออกอาหารสุนัขและแมว
#
# Export_other_animalfeed = ส่งออกอาหารใช้เลี้ยงสัตว์อื่น ๆ
#
# Export_of_petsupplement = ส่งออกอาหารเสริมสัตว์เลี้ยง
#
# Export_premix = ส่งออกพรีมิกซ์
#
# Export_of_cannedfood_dogscats = ส่งออกอาหารกระป๋องสุนัขและแมว
#
# Export_Dog_Chews = ส่งออก Dog Chews
#
# Export_of_aquatic_animalfeed = ส่งออกอาหารสัตว์น้ำ

# %% [markdown]
# ##เรียกคอลั่มแค่คอลั่มที่ต้องการเชื่อมตารางมาดู เพื่อเช็คว่าข้อมูลนั้นใช้งานได้หรือไม่

# %%
Import_df["Country"]

# %%
Export_df["Country"]

# %%
Import_df.shape # .shape เป็นคำสั่งที่ใช้เช็คว่าข้อมูลที่เอามามีความผิดพลาดรึเปล่า จำนวนแถว,จำนวนหลัก

# %%
Export_df.shape # .shape เป็นคำสั่งที่ใช้เช็คว่าข้อมูลที่เอามามีความผิดพลาดรึเปล่า จำนวนแถว,จำนวนหลัก

# %% [markdown]
# ##Missing Values ค่าผิดปกติ เช็คดูว่าตารางเรามี missing

# %%
Import_df.isnull().any() #.isnull ดูว่าแต่ละช่องในตารางมีช่องว่างรึป่าว

# %%
Export_df.isnull().any()# .isnull ดูว่าแต่ละช่องในตารางมีช่องว่างรึป่าว

# %% [markdown]
# ##แก้ไขข้อมูลกำหนดค่าในตาราง เพื่อให้เข้อมูลในตารางนำไปใช้ในการ Assosiation ได้
#
# โดยการเพิ่มคอลั่มใหม่ในตาราง Import_df และ Export_df คอลั่มที่สร้างใหม่นั้นจะตามหลังด้วย _group โดยการจัดกลุ่มให้ค่าทั้งหมดในแต่ละคอลั่ม ซึ่งจัดกลุ่มดังนี้
#
# 1. ถ้ามีค่าตั้งแต่ 10 ตันขึ้นไปจะให้เป็น ' Yes_ชื่อคอลั่มใหม่ที่จัดกลุ่ม ' คือมีการนำเข้าและส่งออก อาหารสัตว์
#
# 2. ถ้ามีค่าน้อยกว่า 10 ตันจะให้เป็น ' No_ชื่อคอลั่มใหม่ที่จัดกลุ่ม ' คือไม่มีการนำเข้าและส่งออกอาหารสัตว์

# %% [markdown]
# ###เพิ่มคอลั่มใหม่ในตาราง Import_df

# %%
Import_df.columns

# %%
Im_mains_bucket = ['No_Im_main','Yes_Im_main'] #กำหนดข้อมูลที่นำไปใส่ในคอลั่มใหม่
Import_df['Im_main_group'] = pd.cut(Import_df.Import_of_main_raw_materials,#เพิ่มคอลั่มใหม่ Im_main_groupในตาราง Import_df 
                            bins=[0,10,10000000], #กำหนดช่วงของข้อมูล เช่น 0,10 คือเริ่มจาก 0 ไปถึง 9.99  โดยจะให้ค่าที่อยู่ในช่วงนี้แทนด้วย No_Im_main
                            labels=Im_mains_bucket,#ข้อมูลที่จะเติมใน Im_mains_bucket มาจาก No_Im_main และ Yes_Im_main ที่กำหนดไว้
                            right=False).astype(str).astype(CategoricalDtype(Im_mains_bucket,ordered=True))

# %%
Im_mixed_bucket = ['No_Im_mixed','Yes_Im_mixed']
Import_df['Im_mixed_group'] = pd.cut(Import_df.Impor_the_mixed,
                            bins=[0,10,10000000],
                            labels=Im_mixed_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_mixed_bucket,ordered=True))

# %%
Im_dairy_bucket = ['No_Im_dairy','Yes_Im_dairy']
Import_df['Im_dairy_group'] = pd.cut(Import_df.Imported_dairy_products,
                            bins=[0,10,10000000],
                            labels=Im_dairy_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_dairy_bucket,ordered=True))

# %%
Im_petsup_bucket = ['No_Im_petsup','Yes_Im_petsup']
Import_df['Im_petsup_group'] = pd.cut(Import_df.Import_of_pet_supplement,
                            bins=[0,10,10000000],
                            labels=Im_petsup_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_petsup_bucket,ordered=True))

# %%
Im_other_bucket = ['No_Im_other','Yes_Im_other']
Import_df['Im_other_group'] = pd.cut(Import_df.Import_other_animal_feed,
                            bins=[0,10,10000000],
                            labels=Im_other_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_other_bucket,ordered=True))

# %%
Import_df

# %% [markdown]
# ###เพิ่มคอลั่มใหม่ในตาราง Export_df

# %%
Ex_fishmeal_bucket = ['No_Ex_fishmeal','Yes_Ex_fishmeal']
Export_df['Ex_fishmeal_group'] = pd.cut(Export_df.Export_of_fishmeal,
                            bins=[0,10,10000000],
                            labels=Ex_fishmeal_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_fishmeal_bucket,ordered=True))

# %%
Ex_dogcatfood_bucket = ['No_Ex_dogcatfood','Yes_Ex_dogcatfood']
Export_df['Ex_dogcatfood_group'] = pd.cut(Export_df.Export_of_dogcat_food	,
                            bins=[0,10,10000000],
                            labels=Ex_dogcatfood_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_dogcatfood_bucket,ordered=True))

# %%
Ex_other_bucket = ['No_Ex_other','Yes_Ex_other']
Export_df['Ex_otherfood_group'] = pd.cut(Export_df.Export_other_animalfeed	,
                            bins=[0,10,10000000],
                            labels=Ex_other_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_other_bucket,ordered=True))

# %%
Ex_petsup_bucket = ['No_Ex_petsup','Yes_Ex_petsup']
Export_df['Ex_petsup_group'] = pd.cut(Export_df.Export_of_petsupplement	,
                            bins=[0,10,10000000],
                            labels=Ex_petsup_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_petsup_bucket,ordered=True))

# %%
Ex_premix_bucket = ['No_Ex_premix','Yes_Ex_premix']
Export_df['Ex_premix_group'] = pd.cut(Export_df.Export_premix	,
                            bins=[0,10,10000000],
                            labels=Ex_premix_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_premix_bucket,ordered=True))

# %%
Ex_canfood_bucket = ['No_Ex_canfood','Yes_Ex_canfood']
Export_df['Ex_canfood_group'] = pd.cut(Export_df.Export_of_cannedfood_dogscats	,
                            bins=[0,10,10000000],
                            labels=Ex_canfood_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_canfood_bucket,ordered=True))

# %%
Ex_DogChews_bucket = ['No_Ex_DogChews','Yes_Ex_DogChews']
Export_df['Ex_DogChews_group'] = pd.cut(Export_df.Export_Dog_Chews	,
                            bins=[0,10,10000000],
                            labels=Ex_DogChews_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_DogChews_bucket,ordered=True))

# %%
Ex_aquatic_bucket = ['No_Ex_aquatic','Yes_Ex_aquatic']
Export_df['Ex_aquatic_group'] = pd.cut(Export_df.Export_of_aquatic_animalfeed	,
                            bins=[0,10,10000000],
                            labels=Ex_aquatic_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_aquatic_bucket,ordered=True))

# %%
Export_df

# %% [markdown]
# ##ตัดตารางให้เหลือแต่กลุ่มของคอลั่มที่ต้องการใช้¶

# %%
Import_df.columns

# %%
#สร้างตารางใหม่ชื่อ Import_df2 ให้เหลือแต่หัวคอลั่มที่ต้องการใช้
Import_df2 = Import_df[["Country","Im_main_group","Im_mixed_group","Im_dairy_group","Im_petsup_group","Im_other_group"]]
Import_df2

# %%
Export_df.columns

# %%
#สร้างตารางใหม่ชื่อ Export_df2 ให้เหลือแต่หัวคอลั่มที่ต้องการใช้
Export_df2 = Export_df[["Country","Ex_fishmeal_group","Ex_dogcatfood_group","Ex_otherfood_group","Ex_petsup_group","Ex_premix_group","Ex_canfood_group","Ex_DogChews_group","Ex_aquatic_group"]]
Export_df2

# %%
Import_df2.shape #ตรวจสอบคอลั่มและแถวว่าตรงตามที่ต้องการหรือไม่

# %%
Export_df2.shape #ตรวจสอบคอลั่มและแถวว่าตรงตามที่ต้องการหรือไม่

# %% [markdown]
# # * loop   ตรวจด้วย

# %%
#Convert data to list 
transacs = []#คือกำหนด transacs ให้เป็น listว่าง
for i in range(0,len(Import_df2)):#เริ่มจาก i ตั้งแต่ 0 ถึง 10000000 
  transacs.append([str(Import_df2.values[i,j]) for j in range(1,6)])#คือการดูข้อมูลตามคอลั่ม#ตอน transection ไม่ต้องการดู Country 
transacs
# Out:
# [['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'No_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'Yes_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'Yes_Im_petsup', 'No_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'Yes_Im_petsup', 'Yes_Im_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'Yes_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'No_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'No_Im_other'],
#  ['Yes_Im_main',
#   'No_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'No_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'No_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other']]

# %%
#Convert data to list 
transacs = []#คือกำหนด transacs ให้เป็น listว่าง
for i in range(0,len(Export_df2)):#เริ่มจาก i ตั้งแต่ 0 ถึง 10000000
  transacs.append([str(Export_df2.values[i,j]) for j in range(1,9)]) #คือการดูข้อมูลตามคอลั่ม#ตอน transection ไม่ต้องการดู Country จึงเริ่มที่ 1-9 
transacs
# Out:
# [['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'Yes_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'Yes_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'Yes_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'No_Ex_canfood',
#   'No_Ex_DogChews',
#   'No_Ex_aquatic']]

# %% [markdown]
# ##รวมตาราง Import_df2 และ Export_df2 โดยใช้ .merge

# %%
Animalfeed_mg = Import_df2.merge(Export_df2,how='left',left_on='Country',right_on='Country')
Animalfeed_mg
# Out:
#            Country Im_main_group  ... Ex_DogChews_group Ex_aquatic_group
# 0        Australia   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 1       Bangladesh    No_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 2          Belgium   Yes_Im_main  ...   Yes_Ex_DogChews   Yes_Ex_aquatic
# 3           Brazil   Yes_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 4         Cambodia    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 5           Canada   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 6            China   Yes_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 7   Czech Republic    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 8          Denmark   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 9          Finland    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 10          France   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 11         Germany   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 12          Greece    No_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 13       Hong Kong    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 14         Hungary    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 15           India   Yes_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 16       Indonesia   Yes_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 17           Italy   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 18           Japan   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 19           Korea   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 20        Malaysia    No_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 21          Mexico    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 22     Netherlands   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 23     New Zealand   Yes_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 24     Philippines    No_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 25         Romania   Yes_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 26          Russia   Yes_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 27    Saudi Arabia   Yes_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 28       Singapore   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 29    South Africa    No_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 30           Spain   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 31          Sweden    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 32          Taiwan   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 33          Turkey   Yes_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 34          U.S.A.   Yes_Im_main  ...   Yes_Ex_DogChews   Yes_Ex_aquatic
# 35         Vietnam   Yes_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
#
# [36 rows x 14 columns]

# %% [markdown]
# ##Assosiation ตาราง Animalfeed_mg

# %% [markdown]
# **Assosiation** เป็นเทคนิคหนึ่งของ Data Mining คือการค้นหาความสัมพันธ์ของข้อมูล
# จากข้อมูลขนาดใหญ่ที่มีอยู่เพื่อจะนำไปหารูปแบบที่เกิดขึ้นบ่อยๆ
# (frequent pattern) และใช้ในการวิเคราะห์ความสัมพันธ์หรือทำนาย
# ปรากฏการณ์ต่างๆ
#
# **Apyori**    เป็นการหาความสัมพันธ์ของข้อมูลจะทำการไล่ transaction ครั้งเดียวในแต่ละระดับชั้น ในการตรวจดูว่า transaction นั้นบรรจุเซตไอเท็มใดบ้าง เพื่อความรวดเร็วจะเก็บเซตไอเท็มในแต่ละระดับชั้นทั้งหมดไว้ในโครงสร้าง Hash Tree (ต้นไม้ของข้อมูลที่ถูกสรุปแล้ว) จุดเด่นความเร็วของการค้นหาไอเท็มเซตที่ปรากฏบ่อย ด้วยการละเว้นการพิจารณาไอเท็มเซตที่ปรากฏซ้าด้วยที่ Confidence ต่ำกว่าเกณฑ์

# %% [markdown]
# **โดยกำหนดให้**
# **Transection** คือ ประเทศนำเข้าและส่งออกอาหารสัตว์มีทั้งหมด 36 ประเทศ
#
# **item** คือ ปริมาณนำเข้าและส่งออกอาหารสัตว์
#
# **ค่าสนับสนุน (Support)** คือ เปอร์เซ็นต์ของจำนวน Item sets ทั้งหมดที่เกิดขึ้นในฐานข้อมูล
#
# **ค่าความเชื่อมั่น (Confidence)** คือ เปอร์เซ็นต์ของจำนวน Item sets ทั้งหมดที่เกิดขึ้นในฐานข้อมูลต่อจำนวน Item sets ที่เกิดขึ้น
#
# **ค่าสหสัมพันธ์ (Lift)** คือค่าที่บ่งบอกว่ากฎมีความสัมพันธ์กัน หรือไม่ โดยถ้าค่าสหสัมพันธ์(Lift) มีค่ามากกว่า 1 แสดงว่ากฎทั้งสองมีความสัมพันธ์กัน แต่ถ้ามีค่าน้อยกว่า 1 แสดงว่า กฎไม่ความสัมพันธ์กันหรือขึ้นต่อกัน (Independent)

# %%
# !pip install apyori
# ทำการติดตั้งแพ็คเกจ apyori
# Out:
# Collecting apyori
#   Downloading https://files.pythonhosted.org/packages/5e/62/5ffde5c473ea4b033490617ec5caa80d59804875ad3c3c57c0976533a21a/apyori-1.1.2.tar.gz
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=901288b3a6354048029d3dc4d01f985637157378e09ff0c368d88282c039a1ee
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
#เปลี่ยนเป็น  7 นะ
Asso = list(apriori(transacs,min_support = 0.70, min_cofidence = 0.70))
Asso
#min_Support  คือค่าสนับสนุนต่ำสุดที่ยอมรับได้ ต่ำกว่านี้จะไม่นำไปวิเคราะห์
#min_Confidence คือ ค่าเชื่อมั่นต่ำสุดที่สนใจ
# Out:
# [RelationRecord(items=frozenset({'No_Ex_DogChews'}), support=0.5277777777777778, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5277777777777778, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_aquatic'}), support=0.7777777777777778, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7777777777777778, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_canfood'}), support=0.3611111111111111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_canfood'}), confidence=0.3611111111111111, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_dogcatfood'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal'}), support=0.7222222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7222222222222222, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_other'}), support=0.8333333333333334, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_other'}), confidence=0.8333333333333334, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup'}), support=0.6944444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup'}), confidence=0.6944444444444444, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_premix'}), support=0.9166666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_premix'}), confidence=0.9166666666666666, lift=1.0)]),
#  RelationRecord(items=frozenset({'Yes_Ex_DogChews'}), support=0.4722222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.4722222222222222, lift=1.0)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood'}), support=0.6388888888888888, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.6388888888888888, lift=1.0)]),
#  RelationRecord(items=frozenset({'Yes_Ex_dogcatfood'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_dogcatfood'}), confidence=0.5, lift=1.0)]),
#  RelationRecord(items=frozenset({'Yes_Ex_petsup'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_petsup'}), confidence=0.3055555555555556, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_aquatic', 'No_Ex_DogChews'}), support=0.3611111111111111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_aquatic'}), confidence=0.3611111111111111, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.6842105263157895, lift=0.8796992481203008), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.46428571428571425, lift=0.8796992481203006)]),
#  RelationRecord(items=frozenset({'No_Ex_canfood', 'No_Ex_DogChews'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_canfood', 'No_Ex_DogChews'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_canfood'}), confidence=0.5789473684210527, lift=1.6032388663967612), OrderedStatistic(items_base=frozenset({'No_Ex_canfood'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.8461538461538463, lift=1.6032388663967614)]),
#  RelationRecord(items=frozenset({'No_Ex_dogcatfood', 'No_Ex_DogChews'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_DogChews'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5789473684210527, lift=1.1578947368421053), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.6111111111111112, lift=1.1578947368421053)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7368421052631579, lift=1.020242914979757), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5384615384615384, lift=1.020242914979757)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_DogChews'}), support=0.4722222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_other'}), confidence=0.4722222222222222, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=0.8947368421052632, lift=1.0736842105263158), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5666666666666667, lift=1.0736842105263158)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.7368421052631579, lift=1.0610526315789472), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.56, lift=1.0610526315789475)]),
#  RelationRecord(items=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), support=0.4722222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.4722222222222222, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.8947368421052632, lift=0.9760765550239235), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5151515151515151, lift=0.9760765550239234)]),
#  RelationRecord(items=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7777777777777778, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), support=0.6111111111111112, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.6111111111111112, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7857142857142858, lift=1.087912087912088), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8461538461538463, lift=1.087912087912088)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_aquatic'}), support=0.6388888888888888, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.6388888888888888, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_other'}), confidence=0.8214285714285714, lift=0.9857142857142857), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7666666666666666, lift=0.9857142857142857)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), support=0.5833333333333334, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), confidence=0.5833333333333334, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.75, lift=1.08), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8400000000000001, lift=1.08)]),
#  RelationRecord(items=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), support=0.75, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.75, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.9642857142857143, lift=1.051948051948052), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8181818181818182, lift=1.051948051948052)]),
#  RelationRecord(items=frozenset({'Yes_Ex_DogChews', 'No_Ex_aquatic'}), support=0.4166666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_aquatic', 'Yes_Ex_DogChews'}), confidence=0.4166666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.5357142857142857, lift=1.134453781512605), OrderedStatistic(items_base=frozenset({'Yes_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8823529411764707, lift=1.1344537815126052)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood', 'No_Ex_aquatic'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_aquatic'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.6428571428571428, lift=1.0062111801242235), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.782608695652174, lift=1.0062111801242237)]),
#  RelationRecord(items=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_aquatic'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'Yes_Ex_dogcatfood'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'Yes_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7777777777777778, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_canfood', 'No_Ex_other'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_canfood', 'No_Ex_other'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_canfood'}), items_add=frozenset({'No_Ex_other'}), confidence=0.923076923076923, lift=1.1076923076923075), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_canfood'}), confidence=0.39999999999999997, lift=1.1076923076923075)]),
#  RelationRecord(items=frozenset({'No_Ex_canfood', 'No_Ex_petsup'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_canfood', 'No_Ex_petsup'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_canfood'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.8461538461538463, lift=1.2184615384615387), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_canfood'}), confidence=0.44000000000000006, lift=1.2184615384615387)]),
#  RelationRecord(items=frozenset({'No_Ex_canfood', 'No_Ex_premix'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_canfood', 'No_Ex_premix'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_canfood'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.8461538461538463, lift=0.9230769230769232), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_canfood'}), confidence=0.33333333333333337, lift=0.9230769230769232)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7777777777777778, lift=1.0769230769230769), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5384615384615384, lift=1.0769230769230769)]),
#  RelationRecord(items=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_other'}), confidence=1.0, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.6, lift=1.2)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood'}), support=0.4722222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood'}), confidence=0.4722222222222222, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.9444444444444444, lift=1.36), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.68, lift=1.36)]),
#  RelationRecord(items=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix'}), support=0.4722222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.4722222222222222, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.9444444444444444, lift=1.0303030303030303), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5151515151515151, lift=1.0303030303030303)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_other'}), confidence=0.923076923076923, lift=1.1076923076923075), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7999999999999999, lift=1.1076923076923075)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), support=0.5833333333333334, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), confidence=0.5833333333333334, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.8076923076923077, lift=1.1630769230769231), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.8400000000000001, lift=1.1630769230769231)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_premix'}), support=0.6944444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix'}), confidence=0.6944444444444444, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.9615384615384616, lift=1.048951048951049), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7575757575757576, lift=1.048951048951049)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'Yes_Ex_DogChews'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'Yes_Ex_DogChews'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.4615384615384615, lift=0.9773755656108597), OrderedStatistic(items_base=frozenset({'Yes_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7058823529411764, lift=0.9773755656108597)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal'}), confidence=0.4444444444444444, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.6153846153846153, lift=0.963210702341137), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.6956521739130435, lift=0.9632107023411371)]),
#  RelationRecord(items=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_fishmeal'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_fishmeal'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'Yes_Ex_dogcatfood'}), confidence=0.4615384615384615, lift=0.923076923076923), OrderedStatistic(items_base=frozenset({'Yes_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.6666666666666666, lift=0.923076923076923)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_other'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_other'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.7999999999999999, lift=1.152), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_other'}), confidence=0.96, lift=1.152)]),
#  RelationRecord(items=frozenset({'No_Ex_premix', 'No_Ex_other'}), support=0.75, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_premix', 'No_Ex_other'}), confidence=0.75, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.8999999999999999, lift=0.9818181818181818), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_other'}), confidence=0.8181818181818182, lift=0.9818181818181818)]),
#  RelationRecord(items=frozenset({'Yes_Ex_DogChews', 'No_Ex_other'}), support=0.3611111111111111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_other', 'Yes_Ex_DogChews'}), confidence=0.3611111111111111, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.4333333333333333, lift=0.9176470588235294), OrderedStatistic(items_base=frozenset({'Yes_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=0.7647058823529412, lift=0.9176470588235295)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood', 'No_Ex_other'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_other'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.6, lift=0.9391304347826087), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'No_Ex_other'}), confidence=0.782608695652174, lift=0.9391304347826087)]),
#  RelationRecord(items=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_other'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'Yes_Ex_dogcatfood'}), confidence=0.39999999999999997, lift=0.7999999999999999), OrderedStatistic(items_base=frozenset({'Yes_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_other'}), confidence=0.6666666666666666, lift=0.7999999999999999)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), support=0.6944444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), confidence=0.6944444444444444, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_premix'}), confidence=1.0, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.7575757575757576, lift=1.0909090909090908)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'Yes_Ex_DogChews'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'Yes_Ex_DogChews'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.44000000000000006, lift=0.931764705882353), OrderedStatistic(items_base=frozenset({'Yes_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.6470588235294118, lift=0.931764705882353)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.56, lift=0.876521739130435), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.6086956521739131, lift=0.8765217391304349)]),
#  RelationRecord(items=frozenset({'No_Ex_premix', 'Yes_Ex_DogChews'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_premix', 'Yes_Ex_DogChews'}), confidence=0.4444444444444444, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.48484848484848486, lift=1.0267379679144386), OrderedStatistic(items_base=frozenset({'Yes_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.9411764705882353, lift=1.0267379679144386)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood', 'No_Ex_premix'}), support=0.6111111111111112, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_premix'}), confidence=0.6111111111111112, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.6666666666666667, lift=1.0434782608695654), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.9565217391304349, lift=1.0434782608695654)]),
#  RelationRecord(items=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_premix'}), support=0.4444444444444444, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.4444444444444444, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'Yes_Ex_dogcatfood'}), confidence=0.48484848484848486, lift=0.9696969696969697), OrderedStatistic(items_base=frozenset({'Yes_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.8888888888888888, lift=0.9696969696969697)]),
#  RelationRecord(items=frozenset({'Yes_Ex_canfood', 'Yes_Ex_DogChews'}), support=0.4166666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_canfood', 'Yes_Ex_DogChews'}), confidence=0.4166666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'Yes_Ex_DogChews'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.8823529411764707, lift=1.3810741687979542), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'Yes_Ex_DogChews'}), confidence=0.6521739130434784, lift=1.3810741687979542)]),
#  RelationRecord(items=frozenset({'Yes_Ex_dogcatfood', 'Yes_Ex_canfood'}), support=0.4166666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Ex_dogcatfood', 'Yes_Ex_canfood'}), confidence=0.4166666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'Yes_Ex_dogcatfood'}), confidence=0.6521739130434784, lift=1.3043478260869568), OrderedStatistic(items_base=frozenset({'Yes_Ex_dogcatfood'}), items_add=frozenset({'Yes_Ex_canfood'}), confidence=0.8333333333333334, lift=1.3043478260869568)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic', 'No_Ex_DogChews'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.5789473684210527, lift=0.9473684210526315), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), confidence=0.3928571428571429, lift=1.0102040816326532), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_aquatic'}), confidence=0.42307692307692313, lift=1.1715976331360949), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.8461538461538463, lift=1.1715976331360949), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7857142857142858, lift=1.0102040816326532), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5, lift=0.9473684210526315)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_aquatic', 'No_Ex_DogChews'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.631578947368421, lift=0.988558352402746), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_other'}), confidence=0.42857142857142855, lift=0.907563025210084), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_aquatic'}), confidence=0.39999999999999997, lift=1.1076923076923075), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=0.923076923076923, lift=1.1076923076923075), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7058823529411764, lift=0.9075630252100839), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5217391304347826, lift=0.9885583524027459)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_aquatic', 'No_Ex_DogChews'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_petsup', 'No_Ex_aquatic'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), confidence=0.631578947368421, lift=1.0827067669172932), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), confidence=0.42857142857142855, lift=1.1020408163265305), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_aquatic'}), confidence=0.48, lift=1.3292307692307692), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.923076923076923, lift=1.3292307692307692), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8571428571428571, lift=1.1020408163265305), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5714285714285714, lift=1.0827067669172932)]),
#  RelationRecord(items=frozenset({'No_Ex_aquatic', 'No_Ex_premix', 'No_Ex_DogChews'}), support=0.3611111111111111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.3611111111111111, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.6842105263157895, lift=0.912280701754386), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.46428571428571425, lift=0.9831932773109243), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_aquatic'}), confidence=0.3939393939393939, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix'}), confidence=1.0, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7647058823529412, lift=0.9831932773109244), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.48148148148148145, lift=0.9122807017543859)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_DogChews'}), support=0.3055555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.3055555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.5789473684210527, lift=1.1578947368421053), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_other'}), confidence=0.6111111111111112, lift=1.2941176470588236), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_DogChews'}), confidence=0.3666666666666667, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=1.0, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.6470588235294118, lift=1.2941176470588236), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.6111111111111112, lift=1.1578947368421053)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_fishmeal', 'No_Ex_DogChews'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.7368421052631579, lift=1.105263157894737), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_other'}), confidence=0.5384615384615384, lift=1.1402714932126696), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), confidence=0.4666666666666667, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=1.0, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.823529411764706, lift=1.1402714932126699), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5833333333333334, lift=1.105263157894737)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_DogChews'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_DogChews'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), confidence=0.631578947368421, lift=1.0827067669172932), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), confidence=0.4615384615384615, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), confidence=0.48, lift=1.2342857142857142), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.8571428571428571, lift=1.2342857142857142), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.8571428571428571, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5714285714285714, lift=1.0827067669172932)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_DogChews'}), support=0.3611111111111111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.3611111111111111, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix'}), confidence=0.6842105263157895, lift=0.985263157894737), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.5, lift=1.0588235294117647), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), confidence=0.3939393939393939, lift=1.0129870129870129), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.9285714285714285, lift=1.0129870129870129), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7647058823529412, lift=1.0588235294117647), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.52, lift=0.9852631578947368)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_other', 'No_Ex_DogChews'}), support=0.3611111111111111, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_petsup', 'No_Ex_other'}), confidence=0.3611111111111111, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_other'}), confidence=0.6842105263157895, lift=1.0263157894736843), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), confidence=0.4333333333333333, lift=1.114285714285714), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_other'}), confidence=0.52, lift=1.1011764705882354), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.7647058823529412, lift=1.1011764705882354), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=0.9285714285714285, lift=1.114285714285714), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_other'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5416666666666667, lift=1.0263157894736843)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_premix', 'No_Ex_DogChews'}), support=0.4166666666666667, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.4166666666666667, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_other'}), confidence=0.7894736842105263, lift=1.0526315789473684), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.5, lift=1.0588235294117647), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_DogChews', 'No_Ex_other'}), confidence=0.4545454545454546, lift=0.9625668449197862), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix'}), confidence=0.8823529411764707, lift=0.9625668449197863), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_other'}), confidence=0.8823529411764707, lift=1.0588235294117647), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_other'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.5555555555555556, lift=1.0526315789473684)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_premix', 'No_Ex_DogChews'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), confidence=0.7368421052631579, lift=1.0610526315789472), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), confidence=0.56, lift=1.1858823529411766), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), confidence=0.42424242424242425, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_premix'}), confidence=1.0, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_DogChews'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.823529411764706, lift=1.1858823529411766), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_DogChews'}), confidence=0.56, lift=1.0610526315789475)]),
#  RelationRecord(items=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood', 'No_Ex_aquatic'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic', 'No_Ex_dogcatfood'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), confidence=0.42857142857142855, lift=1.1020408163265305), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.6666666666666666, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.4615384615384615, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.8571428571428571, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5454545454545454, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8571428571428571, lift=1.1020408163265305)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_aquatic'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.7777777777777778, lift=1.2173913043478262), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.4666666666666667, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_other'}), confidence=1.0, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.6086956521739131, lift=1.2173913043478262), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.7777777777777778, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_aquatic'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood'}), confidence=0.5, lift=1.0588235294117647), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), confidence=0.7777777777777778, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.56, lift=1.4400000000000002), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup'}), confidence=1.0, lift=1.44), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.6666666666666666, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.823529411764706, lift=1.0588235294117647)]),
#  RelationRecord(items=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix', 'No_Ex_aquatic'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.5, lift=1.0588235294117647), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.7777777777777778, lift=1.037037037037037), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), confidence=0.42424242424242425, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_premix'}), confidence=1.0, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_dogcatfood'}), confidence=0.5185185185185185, lift=1.037037037037037), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.823529411764706, lift=1.0588235294117647)]),
#  RelationRecord(items=frozenset({'No_Ex_other', 'No_Ex_fishmeal', 'No_Ex_aquatic'}), support=0.5555555555555556, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.5555555555555556, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.7142857142857143, lift=1.0714285714285716), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_aquatic', 'No_Ex_other'}), confidence=0.7692307692307693, lift=1.2040133779264215), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.6666666666666666, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_other'}), confidence=0.9090909090909091, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.8695652173913044, lift=1.2040133779264215), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8333333333333334, lift=1.0714285714285714)]),
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_aquatic'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), confidence=0.6428571428571428, lift=1.1020408163265305), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), confidence=0.6923076923076923, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.72, lift=1.178181818181818), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup'}), confidence=0.8181818181818181, lift=1.1781818181818182), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.8571428571428571, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_aquatic'}), confidence=0.8571428571428571, lift=1.1020408163265305)]),
# ...
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), support=0.3888888888888889, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.3888888888888889, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.7777777777777778, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.5384615384615384, lift=1.1402714932126696), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_dogcatfood'}), confidence=0.4666666666666667, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.56, lift=1.4400000000000002), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.42424242424242425, lift=1.0909090909090908), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix', 'No_Ex_other'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix'}), confidence=0.7777777777777778, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.823529411764706, lift=1.2890025575447572), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.823529411764706, lift=1.411764705882353), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.5833333333333334, lift=1.2352941176470589), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.6666666666666666, lift=1.4117647058823528), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.56, lift=1.1858823529411766), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_other'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_dogcatfood'}), confidence=0.5833333333333334, lift=1.5), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), confidence=0.5185185185185185, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.56, lift=1.4400000000000002), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), confidence=1.0, lift=1.44), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_petsup', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_premix', 'No_Ex_other'}), confidence=1.0, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_other'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_other'}), items_add=frozenset ...
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'Yes_Ex_canfood', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_premix'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other', 'Yes_Ex_canfood', 'No_Ex_premix'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.4615384615384615, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix'}), confidence=0.39999999999999997, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.48, lift=1.2342857142857142), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.36363636363636365, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.5217391304347826, lift=0.8944099378881987), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup', 'No_Ex_premix'}), confidence=0.5, lift=1.2857142857142856), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.5714285714285714, lift=1.2100840336134453), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_premix'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup', 'No_Ex_other'}), confidence=0.48, lift=1.2342857142857142), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.75, lift=1.125), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal', 'No_Ex_premix'}), confidence=0.5, lift=1.125), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup', 'No_Ex_fishmeal'}), confidence=0.4444444444444444, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix'}), confidence=0.6666666666666666, lift=1.1428571428571428), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.48, lift=1.2342857142857142), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.8571428571428571, lift=1.3416149068322982), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other'}), confidence=0.5454545454545454, lift=0.9350649350649349), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_premix'}), confidence=0.5714285714285714, lift=0.9350649350649349), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), items_add=frozenset({'Yes_Ex_canfood', 'No_Ex_petsup'}), confidence=0.5217391304347826, lift=1.341614906832298), OrderedStatistic(items_base=frozenset({'Yes_Ex_canfood', 'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_premix'}), confidence=0.8571428571428571, lift=1.2342857142857142), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix'}), items_add ...
#  RelationRecord(items=frozenset({'No_Ex_petsup', 'No_Ex_aquatic', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_aquatic', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.42857142857142855, lift=1.1020408163265305), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_premix'}), confidence=0.6666666666666666, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.4615384615384615, lift=1.1868131868131868), OrderedStatistic(items_base=frozenset({'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_aquatic', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.39999999999999997, lift=1.2), OrderedStatistic(items_base=frozenset({'No_Ex_petsup'}), items_add=frozenset({'No_Ex_aquatic', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_dogcatfood', 'No_Ex_premix'}), confidence=0.48, lift=1.44), OrderedStatistic(items_base=frozenset({'No_Ex_premix'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_aquatic', 'No_Ex_fishmeal', 'No_Ex_other', 'No_Ex_dogcatfood'}), confidence=0.36363636363636365, lift=1.090909090909091), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.8571428571428571, lift=1.4693877551020407), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_premix', 'No_Ex_other'}), confidence=0.5454545454545454, lift=1.1550802139037433), OrderedStatistic(items_base=frozenset({'No_Ex_other', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_dogcatfood'}), confidence=0.5217391304347826, lift=1.341614906832298), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.5714285714285714, lift=1.4693877551020407), OrderedStatistic(items_base=frozenset({'No_Ex_premix', 'No_Ex_aquatic'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_dogcatfood', 'No_Ex_other'}), confidence=0.4444444444444444, lift=1.1428571428571428), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_other', 'No_Ex_petsup', 'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.8571428571428571, lift=1.5428571428571427), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.6666666666666666, lift=1.3333333333333333), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood'}), items_add=frozenset({'No_Ex_other', 'No_Ex_fishmeal', 'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.7058823529411764, lift=1.2705882352941176), OrderedStatistic(items_base=frozenset({'No_Ex_dogcatfood', 'No_Ex_premix'}), items_add=frozenset({'No_Ex_other', 'No_Ex_petsup', 'No_Ex_fishmeal', 'No_Ex_aquatic'}), confidence=0.7058823529411764, lift=1.4117647058823528), OrderedStatistic(items_base=frozenset({'No_Ex_fishmeal', 'No_Ex_other'}), items_add=frozenset({'No_Ex_petsup', 'No_Ex_dogcatfood', 'No_Ex_premix', 'No_Ex_aquatic'}), confidence=0.5, lift=1.2857142857142856), OrderedStatistic(items_base=frozenset({'No_Ex_petsup', 'No_Ex_fishmeal'}), items_add=frozenset({ ...

# %%
#สรุปผล ยังไม่เสร็จ ค่าที่ออกมันออก แค่EX ผลเลยออกมาเป็นแบบนี้
 ไม่มีการส่งออกพรีมิกซ์ ก็จะมีโอกาสที่ไม่มีการส่งอออกหารสัตว์น้ำด้วย โดยมีค่า
เชื่อมั่น ที่ 0.ึ75 หรือ 31 % และมีค่าสนับสนุน ที่ 0.75 และมีค่า lift= 1 แสดงว่ามีความสัมพันธ์กัน
