# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/DM_2020'

# %%
import os
import pandas
import pandas as pd

# %%
Import= os.path.join(path,'Import.csv')  #สร้างที่อยู่โดยใช้ os.path.join
Export= os.path.join(path,'Export.csv')

# %%
Import_df = pandas.read_csv(Import)
Import_df.head()
# Out:
#       Country  ...  Import other animal feed
# 0   Australia  ...                   1414.14
# 1  Bangladesh  ...                     21.50
# 2     Belgium  ...                   3093.18
# 3      Brazil  ...                  12945.06
# 4    Cambodia  ...                     60.01
#
# [5 rows x 6 columns]

# %%
import os
import pandas as pd
from pandas.api.types import CategoricalDtype

# %%
Import_bucket = ['No_materials','Yes_materials']
Import_df['materials_group'] = pd.cut(Import_df.Import of main raw materials,
                            bins=[0,10,10000000],
                            labels=Import_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Import_bucket,ordered=True))
Import_df
# Out:
#   File "<ipython-input-43-483dd5b81a87>", line 2
#     Import_df['materials_group'] = pd.cut(Import_df.Import of main raw materials,
#                                                             ^
# SyntaxError: invalid syntax

# %%
Export_df = pandas.read_csv(Export) 
Export_df.head()
# Out:
#       Country  ...  Export of aquatic animal feed
# 0   Australia  ...                        0.00000
# 1  Bangladesh  ...                       13.10476
# 2     Belgium  ...                       17.43253
# 3      Brazil  ...                       14.44400
# 4    Cambodia  ...                        0.00000
#
# [5 rows x 9 columns]

# %%
Import_df.shape # .shape เป็นคำสั่งที่ใช้เช็คว่าข้อมูลที่เอามามีความผิดพลาดรึเปล่า จำนวนแถว,จำนวนหลัก
# Out:
# (36, 6)

# %%
Export_df.shape #
# Out:
# (36, 9)

# %%
Import_df["Country"]
# Out:
# 0          Australia
# 1         Bangladesh
# 2            Belgium
# 3             Brazil
# 4           Cambodia
# 5             Canada
# 6              China
# 7     Czech Republic
# 8            Denmark
# 9            Finland
# 10            France
# 11           Germany
# 12            Greece
# 13         Hong Kong
# 14           Hungary
# 15             India
# 16         Indonesia
# 17             Italy
# 18             Japan
# 19             Korea
# 20          Malaysia
# 21            Mexico
# 22       Netherlands
# 23       New Zealand
# 24       Philippines
# 25           Romania
# 26            Russia
# 27      Saudi Arabia
# 28         Singapore
# 29      South Africa
# 30             Spain
# 31            Sweden
# 32            Taiwan
# 33            Turkey
# 34            U.S.A.
# 35           Vietnam
# Name: Country, dtype: object

# %%
Export_df['Country']
# Out:
# 0          Australia
# 1         Bangladesh
# 2            Belgium
# 3             Brazil
# 4           Cambodia
# 5             Canada
# 6              China
# 7     Czech Republic
# 8            Denmark
# 9            Finland
# 10            France
# 11           Germany
# 12            Greece
# 13         Hong Kong
# 14           Hungary
# 15             India
# 16         Indonesia
# 17             Italy
# 18             Japan
# 19             Korea
# 20          Malaysia
# 21            Mexico
# 22       Netherlands
# 23       New Zealand
# 24       Philippines
# 25           Romania
# 26            Russia
# 27      Saudi Arabia
# 28         Singapore
# 29      South Africa
# 30             Spain
# 31            Sweden
# 32            Taiwan
# 33            Turkey
# 34            U.S.A.
# 35           Vietnam
# Name: Country, dtype: object

# %% [markdown]
# #Missing Values ค่าผิดปกติ เช็คดูว่าตารางเรามี missing

# %%
Import_df.isnull().any()
# Out:
# Country                         False
# Import of main raw materials    False
# Import the mixed                False
# Imported dairy products         False
# Import of pet supplement        False
# Import other animal feed        False
# dtype: bool

# %%
Export_df.isnull().any()
# Out:
# Country                                    False
# Export of fish meal                        False
# Export of dog and cat food                 False
# Export other animal feed                   False
# Export of pet supplement                   False
# Export premix                              False
# Export of canned food for dogs and cats    False
# Export Dog Chews                           False
# Export of aquatic animal feed              False
# dtype: bool

# %%
df.loc = ['Australia']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-342-524dbdfb2c40> in <module>()
# ----> 1 df.loc = ['Australia']
#
# AttributeError: 'list' object has no attribute 'loc'

# %% [markdown]
# #กำหนดค่าในตาราง
# โดยค่าที่กำหนดคือ สินค้าที่นำเข้าและส่งออกในประเทศต่างๆ
#
# ถ้าค่าตั้งแต่ 10 ตัน ขึ้นไปจะให้เป็น ' 1 ' คือ มีการนำเข้าและส่งออก อาหารสัตว์
#
# ถ้าค่าตั้งแต่ 0 ถึง 9.9999 ตัน จะให้เป็น 'คือไม่มีการนำเข้าและส่งออกอาหารสัตว์

# %%
Import_bucket = ['0','1']
Import_df['Import of main raw materials_nw'] = pd.cut(Import_df.Import of main raw materials,
                                                                      bins = [0,10,7010],
                                                                       = number1
                                                                   )

# %%
import numpy as np #แก้ไขข้อมูลเนื่องจากข้อมูลในคอลั่มทั้งหมดเป็นตัวเลขจึงใช้ numpy

# %%
df1= Import_df.iloc[:,1:] #กำหนดให้... 
df1["Import of main raw materials"] = np.where(df1["Import of main raw materials"]>10,1,0)

# %%
df2 = Export_df.iloc[:,1:]
df2["Export of fish meal"] = np.where(df2["Export of fish meal"]>10,1,0) 
df2.head()
# Out:
#    Export of fish meal  ...  Export of aquatic animal feed
# 0                    0  ...                        0.00000
# 1                    1  ...                       13.10476
# 2                    1  ...                       17.43253
# 3                    0  ...                       14.44400
# 4                    0  ...                        0.00000
#
# [5 rows x 8 columns]

# %%
if ('Export of fish meal' > 10) {
    echo "Country  is 1";    
} else if ('Export of fish meal' < 10) {
     echo "Country is 0"; 
}

# %%
Export_df['Export of fish meal'] = Export_df['Export of fish meal'].map({ 'Country>10':1,'Country<10':0})
Export_df

# %%
df= pd.DataFrame
df2 = Import_df.query['Import of main raw materials <10,1']

# %%
df3 = Export_df
df3 = (df3.replace["Export of fish meal"]>10,1,0)
df3.head()

# %%
df.replace

# %%
if  "Import of main raw materials > 10":
    print("1")
else:
    print("0")

# %%
df['Import of main raw materials'] = df['Import of main raw materials'].map(<10:1)

# %%
df3 = df.loc[:,(df>50).all()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-340-24b3021306a2> in <module>()
# ----> 1 df3 = df.loc[:,(df>50).all()]
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
for col_idx,data in df3.iteritems():
    print ("Import of main raw materials :",col_idx)
    print ("Import of main raw materials :>10,1,0")
    print (data,"\n")
# Out:
# Import of main raw materials : Country
# Import of main raw materials :>10,1,0
# 0          Australia
# 1         Bangladesh
# 2            Belgium
# 3             Brazil
# 4           Cambodia
# 5             Canada
# 6              China
# 7     Czech Republic
# 8            Denmark
# 9            Finland
# 10            France
# 11           Germany
# 12            Greece
# 13         Hong Kong
# 14           Hungary
# 15             India
# 16         Indonesia
# 17             Italy
# 18             Japan
# 19             Korea
# 20          Malaysia
# 21            Mexico
# 22       Netherlands
# 23       New Zealand
# 24       Philippines
# 25           Romania
# 26            Russia
# 27      Saudi Arabia
# 28         Singapore
# 29      South Africa
# 30             Spain
# 31            Sweden
# 32            Taiwan
# 33            Turkey
# 34            U.S.A.
# 35           Vietnam
# Name: Country, dtype: object
#
# Import of main raw materials : Export of fish meal
# ...

# %%
df3 =Import_df.replace(10 ,1)

# %% [markdown]
# #รวมตาราง

# %%
Animalfeed= Import_df.merge(Export_df,how='left',left_on='Country',right_on='Country')
Animalfeed
# Out:
#            Country  ... Export of aquatic animal feed
# 0        Australia  ...                       0.00000
# 1       Bangladesh  ...                      13.10476
# 2          Belgium  ...                      17.43253
# 3           Brazil  ...                      14.44400
# 4         Cambodia  ...                       0.00000
# 5           Canada  ...                       0.00000
# 6            China  ...                      17.94300
# 7   Czech Republic  ...                       0.00000
# 8          Denmark  ...                       0.00000
# 9          Finland  ...                       0.00000
# 10          France  ...                       0.00000
# 11         Germany  ...                       0.00000
# 12          Greece  ...                      19.72100
# 13       Hong Kong  ...                       0.74500
# 14         Hungary  ...                       0.00000
# 15           India  ...                      86.66050
# ...
