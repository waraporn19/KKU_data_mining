# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/Matching%20Color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-blob==2.1.0

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
 blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %%
imgA1 = 'F4A28637-60A6-4FD4-9B40-5F6449466AD6.png'
imgA2 = '5251BD8C-A91C-47BB-9C99-F52045781D6B.png'
imgA3 = '57535A8C-C3D0-49A0-9211-53B72F039B75.png'
imgA3_5 = 'C03AB660-88BF-4C69-9D11-8DF6568106C7.png'
imgA4 = '53201223-600A-42F0-8DF4-FFEF5B44CBFB.png'

# %%
full_path_to_file2 = os.path.join(imgA1) #รูปที่ 1 A1
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(imgA2) #รูปที่ 2 A2
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(imgA3) #รูปที่ 3 A3
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(imgA3_5) #รูปที่ 4 A3.5
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(imgA4) #รูปที่ 5 A4
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %% [markdown]
# # BGR to RGB

# %%
#รูปที่ 1 A1 ก่อนปรับขนาดภาพ
img01  = cv2.imread(imgA1)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_img01= cv2.cvtColor(img01, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_img01)#โชว์รูป

# %%
#รูปที่ 2 A2 ก่อนปรับขนาดภาพ
img02  = cv2.imread(imgA2)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_img02= cv2.cvtColor(img02, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_img02)#โชว์รูป

# %%
#รูปที่ 3 A3 ก่อนปรับขนาดภาพ
img03  = cv2.imread(imgA3)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_img03= cv2.cvtColor(img03, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_img03)#โชว์รูป

# %%
#รูปที่ 4 A3.5 ก่อนปรับขนาดภาพ
img03_5  = cv2.imread(imgA3_5)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_img03_5= cv2.cvtColor(img03_5, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_img03_5)#โชว์รูป

# %%
#รูปที่ 5 A4 ก่อนปรับขนาดภาพ
img04  = cv2.imread(imgA4)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_img04= cv2.cvtColor(img04, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_img04)#โชว์รูป

# %% [markdown]
# #RGB to LAB

# %%
#รูปที่ 1 A1 
T01 = cv2.imread(imgA1)#อ่านรูปเข้ามา 
LAB_img01= cv2.cvtColor(T01, cv2.COLOR_RGB2LAB)#แปลง RGB  เป็น LAB
plt.imshow(LAB_img01)#โชว์รูป

# %%
#รูปที่ 2 A2 
T02  = cv2.imread(imgA2)#อ่านรูปเข้ามา 
LAB_img02= cv2.cvtColor(T02, cv2.COLOR_RGB2LAB)#แปลง RGB  เป็น LAB
plt.imshow(LAB_img02)#โชว์รูป

# %%
#รูปที่ 3 A3 
T03  = cv2.imread(imgA3)#อ่านรูปเข้ามา 
LAB_img03= cv2.cvtColor(T03, cv2.COLOR_RGB2LAB)#แปลง RGB  เป็น LAB
plt.imshow(LAB_img03)#โชว์รูป

# %%
#รูปที่ 4 A3.5 
T03_5  = cv2.imread(imgA3_5)#อ่านรูปเข้ามา 
LAB_img03_5= cv2.cvtColor(T03_5, cv2.COLOR_RGB2LAB)#แปลง RGB  เป็น LAB 
plt.imshow(LAB_img03_5)#โชว์รูป

# %%
#รูปที่ 5 A4 
T04  = cv2.imread(imgA4)#อ่านรูปเข้ามา
LAB_img04= cv2.cvtColor(T04, cv2.COLOR_RGB2LAB)#แปลง RGB  เป็น LAB
plt.imshow(LAB_img04)#โชว์รูป

# %% [markdown]
# #ดึงสี

# %%
for i in range(RGB_img01.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_img01.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 2019<i<2131 and 1769<j<1881:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1849 - 2101   ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(RGB_img01[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [84 79 73]
# [88 83 77]
# [93 88 82]
# [96 91 85]
# [91 86 80]
# [75 70 64]
# [76 71 65]
# [76 71 65]
# [86 81 75]
# [85 80 74]
# [93 88 82]
# [83 78 72]
# [82 77 71]
# [88 83 77]
# [88 83 77]
# [81 76 70]
# [80 75 69]
# [83 78 72]
# [84 79 73]
# [85 80 74]
# [88 83 77]
# [80 75 69]
# [77 72 66]
# [80 75 69]
# [81 76 70]
# [81 76 70]
# [74 69 63]
# [74 69 63]
# [81 76 70]
# [83 78 72]
# [76 71 65]
# [79 74 68]
# [79 74 68]
# [68 63 57]
# [68 63 57]
# [64 59 53]
# [70 65 59]
# [70 65 59]
# [71 66 60]
# [78 73 67]
# [94 89 83]
# [87 82 76]
# [85 80 74]
# [83 78 72]
# [93 88 82]
# [89 84 78]
# [100  95  89]
# [100  95  89]
# [101  96  90]
# [96 91 85]
# [95 90 84]
# [94 89 83]
# [91 86 80]
# [77 72 66]
# [82 77 71]
# [80 75 69]
# [78 73 67]
# [85 80 74]
# [89 84 78]
# [88 83 77]
# [84 79 73]
# [81 76 70]
# [79 74 68]
# [81 76 70]
# [93 88 82]
# [88 83 77]
# [87 82 76]
# [86 81 75]
# [87 82 76]
# [93 88 82]
# [93 88 82]
# ...

# %%
for i in range(LAB_img01.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_img01.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 2019<i<2131 and 1769<j<1881:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 2019 - 2131   ค่า j  ที่เข้ามาอยู่ระหว่าง 1769-1881
                    print(LAB_img01[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [ 85 127 124]
# [ 89 127 124]
# [ 95 127 124]
# [ 98 127 124]
# [ 92 127 124]
# [ 75 127 124]
# [ 76 126 124]
# [ 76 126 124]
# [ 87 127 124]
# [ 86 127 124]
# [ 95 127 124]
# [ 84 127 124]
# [ 83 127 124]
# [ 89 127 124]
# [ 89 127 124]
# [ 82 127 124]
# [ 81 127 124]
# [ 84 127 124]
# [ 85 127 124]
# [ 86 127 124]
# [ 89 127 124]
# [ 81 127 124]
# [ 77 126 124]
# [ 81 127 124]
# [ 82 127 124]
# [ 82 127 124]
# [ 74 127 124]
# [ 74 127 124]
# [ 82 127 124]
# [ 84 127 124]
# [ 76 126 124]
# [ 80 127 124]
# [ 80 127 124]
# [ 67 127 124]
# [ 67 127 124]
# [ 63 127 124]
# [ 69 127 124]
# [ 69 127 124]
# [ 70 127 124]
# [ 78 126 124]
# [ 96 126 124]
# [ 88 127 124]
# [ 86 127 124]
# [ 84 127 124]
# [ 95 127 124]
# [ 90 127 124]
# [102 127 124]
# [102 127 124]
# [103 127 124]
# [ 98 127 124]
# [ 97 126 125]
# [ 96 126 124]
# [ 92 127 124]
# [ 77 126 124]
# [ 83 127 124]
# [ 81 127 124]
# [ 78 126 124]
# [ 86 127 124]
# ...

# %%
for i in range(LAB_img02.shape[0]): 
     for j in range(LAB_img02.shape[1]): 
                if 2019<i<2131 and 1769<j<1881:
                    print(LAB_img02[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [ 98 127 124]
# [ 93 127 124]
# [ 80 127 124]
# [ 72 127 124]
# [ 80 127 124]
# [ 87 126 125]
# [ 96 126 125]
# [ 87 126 125]
# [ 94 126 125]
# [ 94 126 125]
# [ 86 126 125]
# [ 88 126 125]
# [ 89 126 125]
# [ 80 126 125]
# [ 85 126 125]
# [ 92 126 125]
# [ 94 126 125]
# [ 85 126 125]
# [ 86 126 125]
# [ 87 127 124]
# [ 81 127 124]
# [ 83 127 124]
# [ 81 127 124]
# [ 85 127 124]
# [ 83 127 124]
# [ 83 127 124]
# [ 83 127 124]
# [ 78 126 125]
# [ 77 126 125]
# [ 76 126 125]
# [ 81 126 125]
# [ 85 126 125]
# [ 83 126 125]
# [ 88 126 125]
# [ 88 126 125]
# [ 83 126 125]
# [ 77 126 125]
# [ 85 126 125]
# [ 83 126 125]
# [ 78 126 125]
# [ 83 126 125]
# [ 86 126 125]
# [ 83 126 125]
# [ 76 126 125]
# [ 85 126 125]
# [ 90 125 125]
# [ 89 126 125]
# [ 78 126 125]
# [ 75 126 125]
# [ 75 126 125]
# [ 79 126 125]
# [ 78 126 124]
# [ 83 127 124]
# [ 80 127 124]
# [ 78 126 124]
# [ 86 127 124]
# [ 83 127 124]
# [ 76 126 124]
# ...

# %%
for i in range(LAB_img03.shape[0]): 
     for j in range(LAB_img03.shape[1]): 
                if 2019<i<2131 and 1769<j<1881:
                    print(LAB_img03[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [ 72 127 124]
# [ 79 127 125]
# [ 75 128 124]
# [ 72 127 124]
# [ 74 127 124]
# [ 71 127 125]
# [ 74 127 124]
# [ 74 127 124]
# [ 66 127 124]
# [ 62 127 124]
# [ 66 127 124]
# [ 77 127 125]
# [ 70 128 124]
# [ 77 127 125]
# [ 73 127 125]
# [ 61 128 124]
# [ 65 127 124]
# [ 73 127 125]
# [ 75 128 124]
# [ 70 128 124]
# [ 73 127 125]
# [ 68 127 124]
# [ 74 127 124]
# [ 69 127 124]
# [ 73 127 125]
# [ 70 128 124]
# [ 72 127 124]
# [ 81 128 124]
# [ 75 128 124]
# [ 69 127 124]
# [ 65 127 124]
# [ 70 128 124]
# [ 83 128 124]
# [ 83 128 124]
# [ 75 128 124]
# [ 72 127 124]
# [ 82 128 124]
# [ 81 128 124]
# [ 75 128 124]
# [ 73 127 125]
# [ 72 127 124]
# [ 75 128 124]
# [ 80 127 124]
# [ 74 127 124]
# [ 85 128 125]
# [ 82 128 124]
# [ 66 127 124]
# [ 65 127 124]
# [ 82 128 124]
# [ 92 128 124]
# [ 91 128 124]
# [ 64 127 124]
# [ 71 127 125]
# [ 81 128 124]
# [ 79 127 125]
# [ 80 127 124]
# [ 69 127 124]
# [ 63 127 124]
# ...

# %%
for i in range(LAB_img03_5.shape[0]): 
     for j in range(LAB_img03_5.shape[1]): 
                if 2019<i<2131 and 1769<j<1881:
                    print(LAB_img03_5[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [ 95 126 127]
# [ 96 127 127]
# [ 90 126 127]
# [ 89 127 127]
# [ 92 127 127]
# [ 74 126 127]
# [ 87 126 127]
# [ 90 126 127]
# [ 83 127 127]
# [ 83 127 127]
# [ 84 127 127]
# [ 90 126 127]
# [ 99 127 127]
# [104 127 127]
# [102 127 127]
# [ 90 126 127]
# [ 83 127 127]
# [ 85 127 127]
# [ 82 127 127]
# [ 98 127 127]
# [ 96 127 127]
# [ 89 127 127]
# [ 87 126 127]
# [ 89 127 127]
# [ 87 126 127]
# [ 84 127 127]
# [ 89 127 127]
# [ 81 127 127]
# [ 81 127 127]
# [ 86 126 127]
# [ 96 127 127]
# [ 91 127 127]
# [ 97 127 127]
# [103 127 127]
# [103 127 127]
# [102 127 127]
# [ 97 127 127]
# [ 99 127 127]
# [ 85 127 127]
# [ 78 126 127]
# [ 91 127 127]
# [ 96 127 127]
# [ 96 127 127]
# [102 127 127]
# [113 126 127]
# [112 127 127]
# [112 127 127]
# [ 98 127 127]
# [101 127 127]
# [109 127 127]
# [103 127 127]
# [ 96 127 127]
# [ 77 127 127]
# [ 73 127 127]
# [ 81 127 127]
# [ 84 127 127]
# [ 86 126 127]
# [ 86 126 127]
# ...

# %%
for i in range(LAB_img04.shape[0]): 
     for j in range(LAB_img04.shape[1]): 
                if 2019<i<2131 and 1769<j<1881:
                    print(LAB_img04[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [ 63 125 125]
# [ 65 126 125]
# [ 73 126 125]
# [ 70 126 125]
# [ 70 126 125]
# [ 68 127 124]
# [ 72 127 124]
# [ 76 126 124]
# [ 66 127 124]
# [ 43 127 124]
# [ 26 126 124]
# [ 27 126 123]
# [ 51 126 124]
# [ 83 127 124]
# [ 84 127 124]
# [ 70 127 124]
# [ 85 127 124]
# [ 89 127 124]
# [ 78 126 124]
# [ 74 127 124]
# [ 85 127 124]
# [ 87 127 124]
# [ 69 127 124]
# [ 63 127 124]
# [ 75 127 124]
# [ 86 127 124]
# [ 84 127 124]
# [ 78 126 124]
# [ 78 126 124]
# [ 60 127 124]
# [ 52 126 124]
# [ 75 127 124]
# [ 54 126 124]
# [ 63 127 124]
# [ 74 127 124]
# [ 75 127 124]
# [ 82 127 124]
# [ 54 126 124]
# [ 32 127 124]
# [ 50 127 124]
# [ 64 127 124]
# [ 66 127 124]
# [ 72 127 124]
# [ 57 126 124]
# [ 73 127 124]
# [ 87 127 124]
# [ 56 126 124]
# [ 59 127 124]
# [ 64 127 124]
# [ 52 126 124]
# [ 82 127 124]
# [ 82 127 124]
# [ 80 127 124]
# [ 77 126 124]
# [ 82 127 124]
# [ 81 127 124]
# [ 74 127 124]
# [ 75 127 124]
# ...

# %% [markdown]
# #วาดกรอบสี่เหลี่ยม

# %%
den01= cv2.rectangle(RGB_img01,(2020,1880),(2130,1770),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_img01)#โชว์รูป

# %%
den02= cv2.rectangle(RGB_img02,(2020,1880),(2130,1770),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_img02)#โชว์รูป

# %%
den03= cv2.rectangle(RGB_img03,(2020,1880),(2130,1770),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_img03)#โชว์รูป

# %%
den03_5= cv2.rectangle(RGB_img03_5,(2020,1880),(2130,1770),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_img03_5)#โชว์รูป

# %%
den04= cv2.rectangle(RGB_img04,(2020,1880),(2130,1770),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_img04)#โชว์รูป
