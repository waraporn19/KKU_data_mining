# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/Project_AnimalFeed_Veryreal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ผู้จัดทำ
#
# 1.นางสาวรัฐพร ลีนาราชรุ่งเรือง 613021020-4
#
# 2.นางสาววราภรณ์ สิทธิวงษ์ 613021022-0

# %% [markdown]
# #เริ่มแรกมีการหาข้อมูลจาก เว็ปไซส์ data.go.th
#
# ###ทำให้เราได้ข้อมูล การนำเข้าอาหารสัตว์ และ การส่งออกอาหารสัตว์ ในปี 2015 มา
#
# ข้อมูลการนำเข้าอาหารสัตว์ : https://data.go.th/dataset/item_de26c80b-0571-4721-8a82-aeed70919906
#
# ข้อมูลการส่งออกอาหารสัตว์ : https://data.go.th/dataset/item_94a0b576-c3ee-45ec-8de6-d07b55921571

# %% [markdown]
# ##วัตถุประสงค์
#
# เพื่อศึกษาความสัมพันธ์ของปริมาณการนำเข้าอาหารสัตว์ A แล้วจะทำให้มีปริมาณส่งออกอาหารสัตว์ B  จะมีโอกาสหรือความน่าจะเป็นเกิดขึ้นหรือไม่
#
# เพื่อศึกษาเป็นความรู้หรือดูความสัมพันธ์ที่ได้จากกระบวนการนี้สามารถนำไปใช้คาดเดาได้ว่าควรนำเข้าอาหารสัตว์และส่งออกอาหารสัตว์เพิ่มขึ้นให้กับแต่ละประเทศเท่าใด ในปีต่อไป

# %% [markdown]
# ###Link Drive เพื่อเข้าไปดูไฟล์ :
# https://drive.google.com/drive/folders/12qg2MvSzteJvS7cF8n66E3vwBDA8nTmZ

# %% [markdown]
# ###จัดการไฟล์ข้อมูลที่ได้
#
# 1. โหลดไฟล์ข้อมูลจากเว็ปไซส์ที่หาข้อมูลได้ ทำให้ได้ไฟล์ข้อมูลมา 2 ไฟล์คือ ไฟล์ข้อมูลการนำเข้าอาหารสัตว์ และไฟล์ข้อมูลการส่งออกอาหารสัตว์ ของปี 2015
# 2.ไฟล์ข้อมูลการส่งออกอาหารสัตว์ ประกอบไปด้วย ข้อมูลปริมาณการส่งออกอาหารสัตว์และมูลค่าของการส่งออกอาหารสัตว์ โดยมีหน่วยเป็นกิโลกรัม ทั้งหมด 54 ประเทศ
#
#    แต่ไฟล์ข้อมูลนำเข้าอาหารสัตว์ ประกอบไปด้วย ข้อมูลปริมาณนำเข้าอาหารสัตว์และมูลค่าของนำเข้าอาหารสัตว์โดยมีหน่วยเป็นตัน ทั้งหมด 70 ประเทศ
#
#    ดังนั้นจากข้อมูลที่ได้ ทำให้เราต้องตัดข้อมูลที่เราไม่ต้องการใช้ออกไปคือ คอลั่มที่เป็นมูลค่าของทั้งตารางนำเข้าและส่งออก รวมถึงคอลั่มที่เป็นปริมาณรวมออกด้วย
#
#    ทำให้ตารางส่งออกอาหารสัตว์เหลือทั้งหมด 9 คอลั่มและ ตารางนำเข้าอาหารสัตว์เหลือทั้งหมด 6 คอลั่ม
# 3. จากนั้นเปลี่ยนหน่วยข้อมูลของตารางส่งออกอาหารสัตว์ที่มีหน่วยเป็นกิโลกรัมให้มีหน่วยเป็นตัน โดยนำค่าในตาราวไปหาร 1000
#
#   และเปลี่ยนข้อมูลในตารางนำเข้าที่เป็น - ให้เป็น 0
# 4. เมื่อหน่วยของทั้ง 2 ตารางเหมือนกันแล้วก็ให้เปลี่ยนข้อมูลภาษาไทยที่อยู่ในทั้ง 2 ตารางเป็นภาษาอังกฤษ
# 5. เราต้องการรวมตารางโดยการใช้ .merge ดังนั้นแถวในตารางของทั้ง 2 ตารางต้องมีจำนวณเท่ากัน เราจึงทำการตัดประเทศที่ไม่ตรงกันของทั้ง 2 ตารางออก ทำให้เหลือประเทศที่เหมือนกันทั้งหมด 36 ประเทศ
# 6. เมื่อแก้ไขตารางเสร็จแล้วก็ save ตารางใหม่เป็น csv โดยตั้งชื่อตารางนำเข้าว่า Import_nw4 และตารางส่งออกว่า Ex_animalfeed_tun3 จากนั้นก็นำตารางลง Drive

# %%
from google.colab import drive 
drive.mount('/content/drive')   #เรียกใช้ข้อมูลจาก Drive ของเรา
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Project_Animal' #ให้ข้อมูลที่อยู่ใน Drive แทนด้วยชื่อ path

# %%
## เรียกใช้ฟังก์ชั่น os และ pandas as pd
import os
import pandas as pd

# %%
from pandas.api.types import CategoricalDtype

# %%
Import= os.path.join(path,'Import_nw4.csv')  #สร้างที่อยู่โดยใช้ os.path.join
Export= os.path.join(path,'Ex_animalfeed_tun3.csv')

# %%
Import_df = pd.read_csv(Import) # อ่านข้อมูลที่อยู่ในไฟล์ Import_nw4 โดยให้อยู่ในชื่อ Import_df
Import_df.head() #เรียกดูตารางในไฟล์ Import
# Out:
#       Country  ...  Import_other_animal_feed
# 0   Australia  ...                   1414.14
# 1  Bangladesh  ...                     21.50
# 2     Belgium  ...                   3093.18
# 3      Brazil  ...                  12945.06
# 4    Cambodia  ...                     60.01
#
# [5 rows x 6 columns]

# %% [markdown]
# ชื่อหัวคอลั่ม Import การนำเข้า
#
# Country = ประเทศที่นำเข้า
#
# Import_of_main_raw_materials = ปริมาณนำเข้าวัตถุดิบหลัก
#
# Import_the_mixed = ปริมาณนำเข้าวัตถุที่ผสมแล้ว
#
# Imported_dairy_products = ปริมาณนำเข้าผลิตภัณฑ์นม
#
# Import_of_pet_supplement = ปริมาณนำเข้าอาหารเสริมสำหรับสัตว์
#
# Import_other_animal_feed = ปริมาณนำเข้าวัตถุดิบอื่นๆ

# %%
Export_df = pd.read_csv(Export) 
Export_df.head() #เรียกตารางมาดู
# Out:
#     Country  Export_of_fishmeal  ...  Export_Dog_Chews  Export_of_aquatic_animalfeed
# 0    U.S.A.                 0.0  ...         124.50461                       28.8402
# 1     Japan              2245.0  ...         118.31314                        0.6375
# 2     China              7010.0  ...           0.00000                       17.9430
# 3  Malaysia                 0.0  ...          61.05034                        0.9100
# 4     Italy                 0.0  ...          17.83016                        0.0000
#
# [5 rows x 9 columns]

# %% [markdown]
# ชื่อหัวคอลั่ม Export การส่งออก
#
# Country = ประเทศที่ส่งออก
#
# Export_of_fishmeal = ปริมาณส่งออกปลาป่น
#
# Export_of_dogcat_food = ปริมาณส่งออกอาหารสุนัขและแมว
#
# Export_other_animalfeed = ปริมาณส่งออกอาหารใช้เลี้ยงสัตว์อื่น ๆ
#
# Export_of_petsupplement = ปริมาณส่งออกอาหารเสริมสัตว์เลี้ยง
#
# Export_premix = ปริมาณส่งออกพรีมิกซ์
#
# Export_of_cannedfood_dogscats = ปริมาณส่งออกอาหารกระป๋องสุนัขและแมว
#
# Export_Dog_Chews = ปริมาณส่งออก Dog Chews
#
# Export_of_aquatic_animalfeed = ปริมาณส่งออกอาหารสัตว์น้ำ

# %% [markdown]
# ##เรียกคอลั่มแค่คอลั่มที่ต้องการเชื่อมตารางมาดู เพื่อเช็คว่าข้อมูลนั้นใช้งานได้หรือไม่

# %%
Import_df["Country"]
# Out:
# 0          Australia
# 1         Bangladesh
# 2            Belgium
# 3             Brazil
# 4           Cambodia
# 5             Canada
# 6              China
# 7     Czech Republic
# 8            Denmark
# 9            Finland
# 10            France
# 11           Germany
# 12            Greece
# 13         Hong Kong
# 14           Hungary
# 15             India
# 16         Indonesia
# 17             Italy
# 18             Japan
# 19             Korea
# 20          Malaysia
# 21            Mexico
# 22       Netherlands
# 23       New Zealand
# 24       Philippines
# 25           Romania
# 26            Russia
# 27      Saudi Arabia
# 28         Singapore
# 29      South Africa
# 30             Spain
# 31            Sweden
# 32            Taiwan
# 33            Turkey
# 34            U.S.A.
# 35           Vietnam
# Name: Country, dtype: object

# %%
Export_df["Country"]
# Out:
# 0             U.S.A.
# 1              Japan
# 2              China
# 3           Malaysia
# 4              Italy
# 5          Australia
# 6              India
# 7            Vietnam
# 8             Taiwan
# 9         Bangladesh
# 10         Indonesia
# 11           Germany
# 12             Korea
# 13       Philippines
# 14             Spain
# 15         Hong Kong
# 16            Canada
# 17            France
# 18         Singapore
# 19       Netherlands
# 20            Brazil
# 21            Russia
# 22           Belgium
# 23       New Zealand
# 24            Greece
# 25            Sweden
# 26      Saudi Arabia
# 27      South Africa
# 28           Denmark
# 29           Finland
# 30           Hungary
# 31           Romania
# 32            Turkey
# 33            Mexico
# 34          Cambodia
# 35    Czech Republic
# Name: Country, dtype: object

# %%
Import_df.shape # .shape เป็นคำสั่งที่ใช้เช็คว่าข้อมูลที่เอามามีความผิดพลาดรึเปล่า จำนวนแถว,จำนวนหลัก
# Out:
# (36, 6)

# %%
Export_df.shape # .shape เป็นคำสั่งที่ใช้เช็คว่าข้อมูลที่เอามามีความผิดพลาดรึเปล่า จำนวนแถว,จำนวนหลัก
# Out:
# (36, 9)

# %% [markdown]
# ##Missing Values ค่าผิดปกติ เช็คดูว่าตารางเรามี missing

# %%
Import_df.isnull().any() #.isnull ดูว่าแต่ละช่องในตารางมีช่องว่างรึป่าว
# Out:
# Country                         False
# Import_of_main_raw_materials    False
# Impor_the_mixed                 False
# Imported_dairy_products         False
# Import_of_pet_supplement        False
# Import_other_animal_feed        False
# dtype: bool

# %%
Export_df.isnull().any()# .isnull ดูว่าแต่ละช่องในตารางมีช่องว่างรึป่าว
# Out:
# Country                          False
# Export_of_fishmeal               False
# Export_of_dogcat_food            False
# Export_other_animalfeed          False
# Export_of_petsupplement          False
# Export_premix                    False
# Export_of_cannedfood_dogscats    False
# Export_Dog_Chews                 False
# Export_of_aquatic_animalfeed     False
# dtype: bool

# %% [markdown]
# ##แก้ไขข้อมูลกำหนดค่าในตาราง เพื่อให้เข้อมูลในตารางนำไปใช้ในการ Assosiation ได้
#
# โดยการเพิ่มคอลั่มใหม่ในตาราง Import_df และ Export_df คอลั่มที่สร้างใหม่นั้นจะตามหลังด้วย _group โดยการจัดกลุ่มให้ค่าทั้งหมดในแต่ละคอลั่ม ซึ่งจัดกลุ่มดังนี้
#
# 1. ถ้ามีค่าตั้งแต่ 10 ตันขึ้นไปจะให้เป็น ' Yes_ชื่อคอลั่มใหม่ที่จัดกลุ่ม ' คือมีการนำเข้าและส่งออก อาหารสัตว์
#
# 2. ถ้ามีค่าน้อยกว่า 10 ตันจะให้เป็น ' No_ชื่อคอลั่มใหม่ที่จัดกลุ่ม ' คือไม่มีการนำเข้าและส่งออกอาหารสัตว์

# %% [markdown]
# ###เพิ่มคอลั่มใหม่ในตาราง Import_df

# %%
Import_df.columns
# Out:
# Index(['Country', 'Import_of_main_raw_materials', 'Impor_the_mixed',
#        'Imported_dairy_products', 'Import_of_pet_supplement',
#        'Import_other_animal_feed'],
#       dtype='object')

# %%
Im_mains_bucket = ['No_Im_main','Yes_Im_main'] #กำหนดข้อมูลที่นำไปใส่ในคอลั่มใหม่
Import_df['Im_main_group'] = pd.cut(Import_df.Import_of_main_raw_materials,#เพิ่มคอลั่มใหม่ Im_main_groupในตาราง Import_df 
                            bins=[0,10,10000000], #กำหนดช่วงของข้อมูล เช่น 0,10 คือเริ่มจาก 0 ไปถึง 9.99  โดยจะให้ค่าที่อยู่ในช่วงนี้แทนด้วย No_Im_main
                            labels=Im_mains_bucket,#ข้อมูลที่จะเติมใน Im_mains_bucket มาจาก No_Im_main และ Yes_Im_main ที่กำหนดไว้
                            right=False).astype(str).astype(CategoricalDtype(Im_mains_bucket,ordered=True))

# %%
Im_mixed_bucket = ['No_Im_mixed','Yes_Im_mixed']
Import_df['Im_mixed_group'] = pd.cut(Import_df.Impor_the_mixed,
                            bins=[0,10,10000000],
                            labels=Im_mixed_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_mixed_bucket,ordered=True))

# %%
Im_dairy_bucket = ['No_Im_dairy','Yes_Im_dairy']
Import_df['Im_dairy_group'] = pd.cut(Import_df.Imported_dairy_products,
                            bins=[0,10,10000000],
                            labels=Im_dairy_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_dairy_bucket,ordered=True))

# %%
Im_petsup_bucket = ['No_Im_petsup','Yes_Im_petsup']
Import_df['Im_petsup_group'] = pd.cut(Import_df.Import_of_pet_supplement,
                            bins=[0,10,10000000],
                            labels=Im_petsup_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_petsup_bucket,ordered=True))

# %%
Im_other_bucket = ['No_Im_other','Yes_Im_other']
Import_df['Im_other_group'] = pd.cut(Import_df.Import_other_animal_feed,
                            bins=[0,10,10000000],
                            labels=Im_other_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Im_other_bucket,ordered=True))

# %%
Import_df
# Out:
#            Country  Import_of_main_raw_materials  ...  Im_petsup_group  Im_other_group
# 0        Australia                     100802.20  ...    Yes_Im_petsup    Yes_Im_other
# 1       Bangladesh                          0.00  ...     No_Im_petsup    Yes_Im_other
# 2          Belgium                      10414.65  ...    Yes_Im_petsup    Yes_Im_other
# 3           Brazil                    1644961.05  ...    Yes_Im_petsup    Yes_Im_other
# 4         Cambodia                          0.00  ...     No_Im_petsup    Yes_Im_other
# 5           Canada                     293925.00  ...    Yes_Im_petsup    Yes_Im_other
# 6            China                      20481.57  ...    Yes_Im_petsup    Yes_Im_other
# 7   Czech Republic                          0.00  ...    Yes_Im_petsup     No_Im_other
# 8          Denmark                      57116.60  ...    Yes_Im_petsup    Yes_Im_other
# 9          Finland                          0.00  ...    Yes_Im_petsup    Yes_Im_other
# ...

# %% [markdown]
# ###เพิ่มคอลั่มใหม่ในตาราง Export_df

# %%
Ex_fishmeal_bucket = ['No_Ex_fishmeal','Yes_Ex_fishmeal']
Export_df['Ex_fishmeal_group'] = pd.cut(Export_df.Export_of_fishmeal,
                            bins=[0,10,10000000],
                            labels=Ex_fishmeal_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_fishmeal_bucket,ordered=True))

# %%
Ex_dogcatfood_bucket = ['No_Ex_dogcatfood','Yes_Ex_dogcatfood']
Export_df['Ex_dogcatfood_group'] = pd.cut(Export_df.Export_of_dogcat_food	,
                            bins=[0,10,10000000],
                            labels=Ex_dogcatfood_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_dogcatfood_bucket,ordered=True))

# %%
Ex_other_bucket = ['No_Ex_other','Yes_Ex_other']
Export_df['Ex_otherfood_group'] = pd.cut(Export_df.Export_other_animalfeed	,
                            bins=[0,10,10000000],
                            labels=Ex_other_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_other_bucket,ordered=True))

# %%
Ex_petsup_bucket = ['No_Ex_petsup','Yes_Ex_petsup']
Export_df['Ex_petsup_group'] = pd.cut(Export_df.Export_of_petsupplement	,
                            bins=[0,10,10000000],
                            labels=Ex_petsup_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_petsup_bucket,ordered=True))

# %%
Ex_premix_bucket = ['No_Ex_premix','Yes_Ex_premix']
Export_df['Ex_premix_group'] = pd.cut(Export_df.Export_premix	,
                            bins=[0,10,10000000],
                            labels=Ex_premix_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_premix_bucket,ordered=True))

# %%
Ex_canfood_bucket = ['No_Ex_canfood','Yes_Ex_canfood']
Export_df['Ex_canfood_group'] = pd.cut(Export_df.Export_of_cannedfood_dogscats	,
                            bins=[0,10,10000000],
                            labels=Ex_canfood_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_canfood_bucket,ordered=True))

# %%
Ex_DogChews_bucket = ['No_Ex_DogChews','Yes_Ex_DogChews']
Export_df['Ex_DogChews_group'] = pd.cut(Export_df.Export_Dog_Chews	,
                            bins=[0,10,10000000],
                            labels=Ex_DogChews_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_DogChews_bucket,ordered=True))

# %%
Ex_aquatic_bucket = ['No_Ex_aquatic','Yes_Ex_aquatic']
Export_df['Ex_aquatic_group'] = pd.cut(Export_df.Export_of_aquatic_animalfeed	,
                            bins=[0,10,10000000],
                            labels=Ex_aquatic_bucket,
                            right=False).astype(str).astype(CategoricalDtype(Ex_aquatic_bucket,ordered=True))

# %%
Export_df
# Out:
#            Country  Export_of_fishmeal  ...  Ex_DogChews_group  Ex_aquatic_group
# 0           U.S.A.               0.000  ...    Yes_Ex_DogChews    Yes_Ex_aquatic
# 1            Japan            2245.000  ...    Yes_Ex_DogChews     No_Ex_aquatic
# 2            China            7010.000  ...     No_Ex_DogChews    Yes_Ex_aquatic
# 3         Malaysia               0.000  ...    Yes_Ex_DogChews     No_Ex_aquatic
# 4            Italy               0.000  ...    Yes_Ex_DogChews     No_Ex_aquatic
# 5        Australia               2.856  ...    Yes_Ex_DogChews     No_Ex_aquatic
# 6            India               0.000  ...     No_Ex_DogChews    Yes_Ex_aquatic
# 7          Vietnam            1840.000  ...     No_Ex_DogChews     No_Ex_aquatic
# 8           Taiwan             141.360  ...    Yes_Ex_DogChews     No_Ex_aquatic
# 9       Bangladesh            1260.000  ...     No_Ex_DogChews    Yes_Ex_aquatic
# 10       Indonesia             480.000  ...     No_Ex_DogChews    Yes_Ex_aquatic
# ...

# %% [markdown]
# ##ตัดตารางให้เหลือแต่กลุ่มของคอลั่มที่ต้องการใช้

# %%
Import_df.columns
# Out:
# Index(['Country', 'Import_of_main_raw_materials', 'Impor_the_mixed',
#        'Imported_dairy_products', 'Import_of_pet_supplement',
#        'Import_other_animal_feed', 'Im_main_group', 'Im_mixed_group',
#        'Im_dairy_group', 'Im_petsup_group', 'Im_other_group'],
#       dtype='object')

# %%
#สร้างตารางใหม่ชื่อ Import_df2 ให้เหลือแต่หัวคอลั่มที่ต้องการใช้
Import_df2 = Import_df[["Country","Im_main_group","Im_mixed_group","Im_dairy_group","Im_petsup_group","Im_other_group"]]
Import_df2
# Out:
#            Country Im_main_group  ... Im_petsup_group Im_other_group
# 0        Australia   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 1       Bangladesh    No_Im_main  ...    No_Im_petsup   Yes_Im_other
# 2          Belgium   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 3           Brazil   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 4         Cambodia    No_Im_main  ...    No_Im_petsup   Yes_Im_other
# 5           Canada   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 6            China   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 7   Czech Republic    No_Im_main  ...   Yes_Im_petsup    No_Im_other
# 8          Denmark   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 9          Finland    No_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 10          France   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 11         Germany   Yes_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# 12          Greece    No_Im_main  ...   Yes_Im_petsup   Yes_Im_other
# ...

# %%
Export_df.columns
# Out:
# Index(['Country', 'Export_of_fishmeal', 'Export_of_dogcat_food',
#        'Export_other_animalfeed', 'Export_of_petsupplement', 'Export_premix',
#        'Export_of_cannedfood_dogscats', 'Export_Dog_Chews',
#        'Export_of_aquatic_animalfeed', 'Ex_fishmeal_group',
#        'Ex_dogcatfood_group', 'Ex_otherfood_group', 'Ex_petsup_group',
#        'Ex_premix_group', 'Ex_canfood_group', 'Ex_DogChews_group',
#        'Ex_aquatic_group'],
#       dtype='object')

# %%
#สร้างตารางใหม่ชื่อ Export_df2 ให้เหลือแต่หัวคอลั่มที่ต้องการใช้
Export_df2 = Export_df[["Country","Ex_fishmeal_group","Ex_dogcatfood_group","Ex_otherfood_group","Ex_petsup_group","Ex_premix_group","Ex_canfood_group","Ex_DogChews_group","Ex_aquatic_group"]]
Export_df2
# Out:
#            Country Ex_fishmeal_group  ... Ex_DogChews_group Ex_aquatic_group
# 0           U.S.A.    No_Ex_fishmeal  ...   Yes_Ex_DogChews   Yes_Ex_aquatic
# 1            Japan   Yes_Ex_fishmeal  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 2            China   Yes_Ex_fishmeal  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 3         Malaysia    No_Ex_fishmeal  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 4            Italy    No_Ex_fishmeal  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 5        Australia    No_Ex_fishmeal  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 6            India    No_Ex_fishmeal  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 7          Vietnam   Yes_Ex_fishmeal  ...    No_Ex_DogChews    No_Ex_aquatic
# 8           Taiwan   Yes_Ex_fishmeal  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 9       Bangladesh   Yes_Ex_fishmeal  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 10       Indonesia   Yes_Ex_fishmeal  ...    No_Ex_DogChews   Yes_Ex_aquatic
# ...

# %%
Import_df2.shape #ตรวจสอบคอลั่มและแถวว่าตรงตามที่ต้องการหรือไม่
# Out:
# (36, 6)

# %%
Export_df2.shape #ตรวจสอบคอลั่มและแถวว่าตรงตามที่ต้องการหรือไม่
# Out:
# (36, 9)

# %% [markdown]
# ###ทำการ loop ตรวจข้อมูลในแต่ประเทศ โดยการกำหนด transacs1 และ transacs2 เป็น listว่าง

# %%
#Convert data to list 
transacs1 = []#คือกำหนด transacs ให้เป็น listว่าง
for i in range(0,len(Import_df2)):#เริ่มจาก i ตั้งแต่ 0 ถึง 10000000 
  transacs1.append([str(Import_df2.values[i,j]) for j in range(1,6)])#คือการดูข้อมูลตามคอลั่ม#ตอน transection ไม่ต้องการดู Country 
transacs1
# Out:
# [['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'No_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'Yes_Im_mixed', 'No_Im_dairy', 'No_Im_petsup', 'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main', 'No_Im_mixed', 'No_Im_dairy', 'Yes_Im_petsup', 'No_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
# ...

# %%
#Convert data to list 
transacs2 = []#คือกำหนด transacs ให้เป็น listว่าง
for i in range(0,len(Export_df2)):#เริ่มจาก i ตั้งแต่ 0 ถึง 10000000
  transacs2.append([str(Export_df2.values[i,j]) for j in range(1,9)]) #คือการดูข้อมูลตามคอลั่ม#ตอน transection ไม่ต้องการดู Country จึงเริ่มที่ 1-9 
transacs2
# Out:
# [['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['Yes_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'No_Ex_DogChews',
#   'Yes_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'Yes_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other',
#   'No_Ex_petsup',
#   'No_Ex_premix',
#   'Yes_Ex_canfood',
#   'Yes_Ex_DogChews',
#   'No_Ex_aquatic'],
#  ['No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other',
#   'Yes_Ex_petsup',
#   'No_Ex_premix',
# ...

# %% [markdown]
# ##รวมตาราง Import_df2 และ Export_df2 โดยใช้ .merge

# %%
Animalfeed_mg = Import_df2.merge(Export_df2,how='left',left_on='Country',right_on='Country') #ใช้คำสั่ง.merge รวมตาราง  Import_df2 และตารางExport_df2 รวมเข้าด้วยกันโดยที่มีคีย์เป็นตัวเชื่อมคือ Country  และ Country
Animalfeed_mg
# Out:
#            Country Im_main_group  ... Ex_DogChews_group Ex_aquatic_group
# 0        Australia   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 1       Bangladesh    No_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 2          Belgium   Yes_Im_main  ...   Yes_Ex_DogChews   Yes_Ex_aquatic
# 3           Brazil   Yes_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 4         Cambodia    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 5           Canada   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 6            China   Yes_Im_main  ...    No_Ex_DogChews   Yes_Ex_aquatic
# 7   Czech Republic    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 8          Denmark   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 9          Finland    No_Im_main  ...    No_Ex_DogChews    No_Ex_aquatic
# 10          France   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# 11         Germany   Yes_Im_main  ...   Yes_Ex_DogChews    No_Ex_aquatic
# ...

# %% [markdown]
# ##Assosiation ตาราง Animalfeed_mg

# %% [markdown]
# **Assosiation** เป็นเทคนิคหนึ่งของ Data Mining คือการค้นหาความสัมพันธ์ของข้อมูล
# จากข้อมูลขนาดใหญ่ที่มีอยู่เพื่อจะนำไปหารูปแบบที่เกิดขึ้นบ่อยๆ
# (frequent pattern) และใช้ในการวิเคราะห์ความสัมพันธ์หรือทำนาย
# ปรากฏการณ์ต่างๆ
#
# **Apyori**    เป็นการหาความสัมพันธ์ของข้อมูลจะทำการไล่ transaction ครั้งเดียวในแต่ละระดับชั้น ในการตรวจดูว่า transaction นั้นบรรจุเซตไอเท็มใดบ้าง เพื่อความรวดเร็วจะเก็บเซตไอเท็มในแต่ละระดับชั้นทั้งหมดไว้ในโครงสร้าง Hash Tree (ต้นไม้ของข้อมูลที่ถูกสรุปแล้ว) จุดเด่นความเร็วของการค้นหาไอเท็มเซตที่ปรากฏบ่อย ด้วยการละเว้นการพิจารณาไอเท็มเซตที่ปรากฏซ้าด้วยที่ Confidence ต่ำกว่าเกณฑ์

# %% [markdown]
# **โดยกำหนดให้**
# **Transection** คือ ประเทศนำเข้าและส่งออกอาหารสัตว์มีทั้งหมด 36 ประเทศ
#
# **item** คือ ปริมาณนำเข้าและส่งออกอาหารสัตว์
#
# **ค่าสนับสนุน (Support)** คือ เปอร์เซ็นต์ของจำนวน Item sets ทั้งหมดที่เกิดขึ้นในฐานข้อมูล
#
# **ค่าความเชื่อมั่น (Confidence)** คือ เปอร์เซ็นต์ของจำนวน Item sets ทั้งหมดที่เกิดขึ้นในฐานข้อมูลต่อจำนวน Item sets ที่เกิดขึ้น
#
# **ค่าสหสัมพันธ์ (Lift)** คือค่าที่บ่งบอกว่ากฎมีความสัมพันธ์กัน หรือไม่ โดยถ้าค่าสหสัมพันธ์(Lift) มีค่ามากกว่า 1 แสดงว่ากฎทั้งสองมีความสัมพันธ์กัน แต่ถ้ามีค่าน้อยกว่า 1 แสดงว่า กฎไม่ความสัมพันธ์กันหรือขึ้นต่อกัน (Independent)

# %% [markdown]
# ###ทำการ loopอีกครั้งเพื่อตรวจข้อมูลในแต่ประเทศจากตารางที่ทำการ .merge มาแล้วว่ามีคำตอบเป็นอย่างไรบ้าง โดยกำหนดให้ transacs3 เป็น listว่าง

# %%
#Convert data to list 
transacs3 = []#คือกำหนด transacs ให้เป็น listว่าง
for i in range(0,len(Animalfeed_mg)):#เริ่มจาก i ตั้งแต่ 0 ถึง 10000000
  transacs3.append([str(Animalfeed_mg.values[i,j]) for j in range(1,9)]) #คือการดูข้อมูลตามคอลั่ม #ตอน transection ไม่ต้องการดู Country จึงเริ่มที่ 1-9 
transacs3
# Out:
# [['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other',
#   'No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other'],
#  ['No_Im_main',
#   'No_Im_mixed',
#   'No_Im_dairy',
#   'No_Im_petsup',
#   'Yes_Im_other',
#   'Yes_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other',
#   'Yes_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other'],
#  ['Yes_Im_main',
#   'No_Im_mixed',
#   'No_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other',
#   'No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other'],
#  ['No_Im_main',
#   'Yes_Im_mixed',
#   'No_Im_dairy',
#   'No_Im_petsup',
#   'Yes_Im_other',
#   'No_Ex_fishmeal',
#   'No_Ex_dogcatfood',
#   'No_Ex_other'],
#  ['Yes_Im_main',
#   'Yes_Im_mixed',
#   'Yes_Im_dairy',
#   'Yes_Im_petsup',
#   'Yes_Im_other',
#   'No_Ex_fishmeal',
#   'Yes_Ex_dogcatfood',
#   'No_Ex_other'],
# ...

# %%
# !pip install apyori
# ทำการติดตั้งแพ็คเกจ apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=c12de57b66198e293aa3aa298f62f6e600bb6defafa3f8cd3f974d508725ddc1
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
Asso = list(apriori(transacs3,min_support = 0.70, min_cofidence = 0.70))
Asso
#min_Support  คือค่าสนับสนุนต่ำสุดที่ยอมรับได้ ต่ำกว่านี้จะไม่นำไปวิเคราะห์
#min_Confidence คือ ค่าเชื่อมั่นต่ำสุดที่สนใจ
# Out:
# [RelationRecord(items=frozenset({'No_Ex_fishmeal'}), support=0.7222222222222222, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_fishmeal'}), confidence=0.7222222222222222, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Ex_other'}), support=0.8333333333333334, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Ex_other'}), confidence=0.8333333333333334, lift=1.0)]),
#  RelationRecord(items=frozenset({'No_Im_dairy'}), support=0.7777777777777778, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'No_Im_dairy'}), confidence=0.7777777777777778, lift=1.0)]),
#  RelationRecord(items=frozenset({'Yes_Im_other'}), support=0.9166666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Yes_Im_other'}), confidence=0.9166666666666666, lift=1.0)]),
# ...

# %% [markdown]
# #สรุปผล
#
#  1.ไม่มีการส่งออกอาหารใช้เลี้ยงสัตว์อื่น ๆ ก็จะมีโอกาสที่ไม่มีการนำเข้าวัตถุดิบอื่นๆ โดยมีค่า
# เชื่อมั่น ที่ 0.
# 75 และมีค่าสนับสนุน ที่ 0.75 และมีค่า lift= 1 แสดงว่ามีความสัมพันธ์กัน
#
#  2.มีการนำเข้าอาหารเสริมสำหรับเลี้ยงสัตว์ ก็จะมีโอกาสที่มีการนำเข้าวัตถุดิบอื่นๆ โดยมีค่า
# เชื่อมั่น ที่ 0.77และมีค่าสนับสนุน ที่ 0.77 และมีค่า lift= 1 แสดงว่ามีความสัมพันธ์กัน
