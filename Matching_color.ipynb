# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/Matching_color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-blob==2.1.0

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
 blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %%
img_8884 = 'FAB352D9-639D-46CB-BE0C-257E75DF55E8.png'

# %%
full_path_to_file2 = os.path.join(img_8884)
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %%
#ลองหาค่าสี
img= cv2.imread(img_8884)
def clickPosition(event,x,y,flags,param):
     if event == cv2.EVENT_LBUTTONDOWN:
          cv2.putText(img,"Ok",(x,y),cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,1,(0,0,225),cv2.LINE_4)
          cv2_imshow(img)      
          cv2.setMouseCallback(img,clickPosition)

# %%
cv2_imshow =  cv2.imread(img_8884)

# %%
#ก่อนปรับขนาดภาพ
img= cv2.imread(img_8884)
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
data =plt.plot([1890,2044,2044,1890,1890],[1800,1800,1950,1950,1800],alpha=0.6,c='r')

# %%
#หลังปรับขนาดภาพ
img = cv2.imread(img_8884)#อ่านภาพ
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
resized_image = cv2.resize(RGB_img,(480,400))#กำหนดขนาดภาพ
imgA1 = cv2.rectangle(resized_image,(220,260),(250,240),(255,0,0),1) #วาดสี่เหลี่ยม
plt.imshow()

# %% [markdown]
# ##ดึงสี

# %%
pixel_values =list(imgA1)
pixel_values
# Out:
# [array([[215, 216, 211],
#         [214, 215, 210],
#         [215, 215, 213],
#         ...,
#         [184, 183, 179],
#         [188, 187, 183],
#         [188, 186, 183]], dtype=uint8), array([[216, 216, 214],
#         [217, 217, 215],
#         [215, 215, 213],
#         ...,
#         [175, 174, 170],
#         [181, 180, 175],
#         [185, 184, 180]], dtype=uint8), array([[222, 222, 219],
#         [219, 219, 217],
#         [214, 214, 212],
#         ...,
#         [175, 173, 170],
#         [180, 179, 175],
#         [182, 181, 177]], dtype=uint8), array([[215, 215, 213],
#         [216, 216, 214],
#         [218, 218, 216],
#         ...,
#         [177, 176, 172],
#         [184, 183, 179],
#         [180, 180, 175]], dtype=uint8), array([[214, 215, 210],
#         [214, 215, 210],
#         [215, 215, 213],
#         ...,
#         [181, 180, 176],
#         [182, 183, 178],
#         [182, 181, 177]], dtype=uint8), array([[213, 214, 209],
#         [215, 216, 211],
# ...

# %%
import numpy

# %%
import PIL
from PIL import Image

# %%
img_8884 = img_8884.resize((400,250), PIL.Image.ANTIALIAS)
print('resize finish')
img_8884.save('FAB352D9-639D-46CB-BE0C-257E75DF55E8.png')

# %%
RGB_img.shape
# Out:
# (3024, 4032, 3)

# %%
RGB_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
data = ([1890,2044,2044,1890,1890],[1800,1800,1950,1950,1800])

# %%
RGB_img
# Out:
# array([[[216, 217, 212],
#         [217, 218, 213],
#         [218, 219, 214],
#         ...,
#         [174, 173, 169],
#         [179, 178, 174],
#         [180, 179, 175]],
#
#        [[216, 217, 212],
#         [217, 218, 213],
#         [218, 219, 214],
#         ...,
#         [176, 175, 171],
#         [173, 172, 168],
#         [179, 178, 174]],
#
#        [[216, 217, 212],
#         [217, 218, 213],
#         [217, 218, 213],
#         ...,
#         [183, 182, 178],
#         [174, 173, 169],
#         [172, 171, 167]],
#
#        ...,
#
#        [[177, 178, 173],
#         [176, 177, 172],
#         [177, 178, 173],
#         ...,
#         [150, 149, 147],
#         [149, 148, 146],
#         [150, 149, 147]],
#
#        [[175, 176, 171],
#         [180, 181, 176],
#         [174, 175, 170],
#         ...,
#         [151, 150, 148],
#         [149, 148, 146],
#         [149, 148, 146]],
#
#        [[180, 181, 176],
#         [178, 179, 174],
#         [173, 174, 169],
# ...

# %%
import numpy as np

# %%
new_img = np.zeros(RGB_img.shape)
for i in range(RGB_img.shape[0]):
     for j in range(RGB_img.shape[1]):
          new_img[i,j,:] = Clus_cen[myQuantize.predict([RGB_img[i,j,:]]), :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-77bff01ec64c> in <module>()
#       3 for i in range(RGB_img.shape[0]):
#       4      for j in range(RGB_img.shape[1]):
# ----> 5           new_img[i,j,:] = Clus_cen[myQuantize.predict([RGB_img[i,j,:]]), :]
#
# NameError: name 'Clus_cen' is not defined
