# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/KKU_data_mining/blob/master/Matching_Color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-blob==2.1.0
# Out:
# ...
#      |████████████████████████████████| 88 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 47 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 10.7 MB/s
# ...

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
 blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %%
img_8884 = 'FAB352D9-639D-46CB-BE0C-257E75DF55E8.png'
img_8870= '7149FEE5-7AD7-476F-8DB8-9DBA080140A0.png'
img_8945= 'D8F49A44-3459-4460-AA70-64633EE671FC.png'
img_8977= '460FAD9C-8D22-476F-AF87-10E75D5B3C10.png'
img_9013 = 'D2BAF78A-7431-4AAA-98FE-719E03EA189B.png'
img_9024 = '3F758FC2-2357-4BAF-AA40-E7E1F3B8832C.png'
img_9034 = '8D9959BD-31DD-4162-B86C-E8A0C0B197EF.png'
img_9044 = '7234B1DA-C86D-4957-85F7-724D9BE7FE30.png'

# %%
full_path_to_file2 = os.path.join(img_8884) #รูปที่ 1 A4
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_8870)#รูปที่ 2 A3.5
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_8945)#รูปที่ 3 B2
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_8977)#รูปที่ 4 C1
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9013) #รูปที่ 5 C2
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9024) #รูปที่  6 C3
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9034) #รูปที่ 7  C4
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(img_9044) #รูปที่ 8  D2 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %% [markdown]
# #เตรียมภาพ

# %%
#รูปที่ 1 A4  ก่อนปรับขนาดภาพ
imgA4  = cv2.imread(img_8884)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgA4 = cv2.cvtColor(imgA4, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgA4)#โชว์รูป

# %%
#รูปที่ 2 A3.5  ก่อนปรับขนาดภาพ
imgA3_5= cv2.imread(img_8870)#อ่านรูปเข้ามา ให้เก็บไว้ในimgA3_5
RGB_imgA3_5 = cv2.cvtColor(imgA3_5, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgA3_5)#โชว์รู

# %%
#รูปที่ 3 B2  ก่อนปรับขนาดภาพ
imgB2= cv2.imread(img_8945)#อ่านรูป
RGB_imgB2 = cv2.cvtColor(imgB2, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgB2)#โชว์รูป

# %%
#รูปที่ 4  C1  ก่อนปรับขนาดภาพ
imgC1= cv2.imread(img_8977)#อ่านรูป
RGB_imgC1 = cv2.cvtColor(imgC1, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC1)#โชว์รูปRGB เต็ม

# %%
#รูปที่ 5 C2  ก่อนปรับขนาดภาพ
imgC2 = cv2.imread(img_9013)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC2 = cv2.cvtColor(imgC2, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC2)#โชว์รูป

# %%
#รูปที่ 6  C3  ก่อนปรับขนาดภาพ
imgC3 = cv2.imread(img_9024)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC3 = cv2.cvtColor(imgC3, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC3)#โชว์รูป

# %%
#รูปที่ 7 C4  ก่อนปรับขนาดภาพ
imgC4 = cv2.imread(img_9034)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgC4 = cv2.cvtColor(imgC4, cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgC4)#โชว์รูป

# %%
#รูปที่ 8 D2  ก่อนปรับขนาดภาพ
imgD2 = cv2.imread(img_9044)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A4
RGB_imgD2 = cv2.cvtColor(imgD2 , cv2.COLOR_BGR2RGB)#แปลง BGR เป็น RGB
plt.imshow(RGB_imgD2)#โชว์รูป

# %% [markdown]
# #ดึงสี RGB

# %%
for i in range(RGB_imgA4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgA4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1849<i<2101 and 1799<j<2001:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1849 - 2101   ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(RGB_imgA4[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [181 180 175]
# [183 182 177]
# [188 187 182]
# [188 187 182]
# [187 186 181]
# [188 187 182]
# [190 189 184]
# [185 184 179]
# [184 183 178]
# [182 181 176]
# [183 182 177]
# [185 184 179]
# [183 182 177]
# [181 180 175]
# [182 181 176]
# [188 187 183]
# [187 186 182]
# [184 183 178]
# [185 184 179]
# [189 188 183]
# [183 182 177]
# [181 180 175]
# [186 185 180]
# [186 185 180]
# [182 181 176]
# [184 184 176]
# [185 185 177]
# [184 184 176]
# [185 185 177]
# [188 188 180]
# [185 185 177]
# [178 179 173]
# [182 183 177]
# [192 191 186]
# [193 192 187]
# [186 185 180]
# [187 186 181]
# [194 194 186]
# [195 195 187]
# [197 197 189]
# [193 193 185]
# [191 188 181]
# [189 186 179]
# [191 188 181]
# [189 186 179]
# [186 183 176]
# [187 184 177]
# [196 193 186]
# [193 190 183]
# [187 184 177]
# [193 190 183]
# [200 197 190]
# [194 191 184]
# [191 188 181]
# [191 188 181]
# [188 185 178]
# [188 185 178]
# [186 183 174]
# ...

# %%
#รูปที่ 2 A3.5
for i in range(RGB_imgA3_5.shape[0]):
     for j in range(RGB_imgA3_5.shape[1]):
                if 1849<i<2101 and 1799<j<2001:
                    print(RGB_imgA3_5[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [186 187 182]
# [181 182 177]
# [182 183 178]
# [182 183 178]
# [179 180 175]
# [181 182 177]
# [177 178 173]
# [183 184 179]
# [186 187 182]
# [187 186 182]
# [185 184 180]
# [182 181 176]
# [180 179 174]
# [181 180 175]
# [184 183 178]
# [185 184 179]
# [186 185 180]
# [189 188 183]
# [184 183 178]
# [188 185 180]
# [179 176 169]
# [178 173 167]
# [179 175 166]
# [179 175 166]
# [172 168 159]
# [168 164 153]
# [169 165 154]
# [168 164 153]
# [163 159 148]
# [157 153 141]
# [157 151 139]
# [162 154 141]
# [164 156 143]
# [162 154 141]
# [164 156 143]
# [162 154 141]
# [160 152 139]
# [163 155 142]
# [159 151 138]
# [155 147 134]
# [162 154 141]
# [164 154 142]
# [164 154 142]
# [158 148 136]
# [155 145 133]
# [161 151 139]
# [159 149 137]
# [158 148 136]
# [163 153 141]
# [162 152 140]
# [158 148 136]
# [156 146 134]
# [158 148 136]
# [160 150 138]
# [158 148 136]
# [156 146 134]
# [155 145 133]
# [157 147 135]
# ...

# %%
#รูปที่ 3 B2
for i in range(RGB_imgB2.shape[0]):
     for j in range(RGB_imgB2.shape[1]):
                if 1849<i<2101 and 1799<j<2001:
                    print(RGB_imgB2[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [46 44 47]
# [61 59 62]
# [52 50 53]
# [47 45 48]
# [46 44 47]
# [52 50 53]
# [51 49 52]
# [51 49 52]
# [47 45 48]
# [44 42 45]
# [45 43 46]
# [47 45 48]
# [43 41 44]
# [48 46 49]
# [50 48 51]
# [43 41 44]
# [50 48 51]
# [60 58 61]
# [47 45 48]
# [45 43 46]
# [59 57 60]
# [58 56 59]
# [59 57 60]
# [48 43 47]
# [52 47 51]
# [62 57 61]
# [60 55 59]
# [57 52 56]
# [59 54 58]
# [57 52 56]
# [56 51 55]
# [53 48 52]
# [59 54 58]
# [61 56 60]
# [57 52 56]
# [51 46 50]
# [61 56 60]
# [60 55 59]
# [62 57 61]
# [54 49 53]
# [55 50 54]
# [54 49 53]
# [59 54 58]
# [57 52 56]
# [56 51 55]
# [63 58 62]
# [54 49 53]
# [56 51 55]
# [61 56 60]
# [52 47 51]
# [48 43 47]
# [53 48 52]
# [48 43 47]
# [48 43 47]
# [50 45 49]
# [59 54 58]
# [54 49 53]
# [47 42 46]
# [59 54 58]
# [58 53 57]
# [57 52 56]
# [51 46 50]
# [61 56 60]
# [65 60 66]
# [55 50 56]
# [56 51 57]
# [55 50 56]
# [49 47 52]
# [55 53 58]
# [58 56 61]
# [55 53 58]
# [51 49 54]
# ...

# %%
#รูปที่ 4 C1
for i in range(RGB_imgC1.shape[0]):
     for j in range(RGB_imgC1.shape[1]):
                if 1849<i<2101 and 1799<j<2001:
                    print(RGB_imgC1[i][j])
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [39 44 47]
# [31 36 39]
# [42 47 50]
# [42 47 50]
# [45 50 53]
# [33 38 41]
# [33 38 41]
# [37 42 45]
# [35 40 43]
# [35 40 43]
# [39 44 47]
# [38 43 46]
# [29 34 37]
# [26 31 34]
# [27 32 35]
# [43 48 51]
# [35 40 43]
# [31 36 39]
# [34 39 42]
# [40 45 48]
# [40 45 48]
# [42 47 50]
# [50 55 58]
# [36 41 44]
# [45 50 53]
# [42 47 50]
# [36 41 44]
# [43 48 51]
# [34 39 42]
# [33 38 41]
# [41 46 49]
# [27 32 35]
# [22 27 30]
# [39 44 47]
# [41 46 49]
# [36 41 44]
# [34 39 42]
# [28 33 36]
# [31 36 39]
# [40 45 48]
# [36 41 44]
# [29 34 37]
# [33 38 41]
# [37 42 45]
# [32 37 40]
# [39 44 47]
# [39 44 47]
# [30 35 38]
# [25 30 33]
# [37 42 45]
# [41 46 49]
# [45 50 53]
# [40 45 48]
# [29 34 37]
# [28 33 36]
# [27 32 35]
# [34 39 42]
# [35 40 43]
# [41 46 49]
# [40 45 48]
# [42 47 50]
# [42 47 50]
# [33 38 41]
# [36 41 44]
# [36 41 44]
# [38 43 46]
# [37 42 45]
# [29 34 37]
# [41 46 49]
# [42 47 50]
# [28 33 36]
# [25 30 33]
# ...

# %%
for i in range(RGB_imgC2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024 colum
                if 1849<i<2101 and 1799<j<2001:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1849-2101  ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(RGB_imgC2[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [44 48 49]
# [43 47 48]
# [49 53 54]
# [46 50 51]
# [41 45 46]
# [39 43 44]
# [43 47 48]
# [41 45 46]
# [38 42 43]
# [47 51 52]
# [39 43 44]
# [35 39 40]
# [42 46 47]
# [38 42 43]
# [37 41 42]
# [43 47 48]
# [41 45 46]
# [41 45 46]
# [41 45 46]
# [30 34 35]
# [35 39 40]
# [28 32 33]
# [26 30 31]
# [36 40 41]
# [40 44 45]
# [39 43 44]
# [26 30 31]
# [31 35 36]
# [31 35 36]
# [29 33 34]
# [31 35 36]
# [33 37 38]
# [34 38 39]
# [29 33 34]
# [31 35 36]
# [43 47 48]
# [38 42 43]
# [37 41 42]
# [46 50 51]
# [46 50 51]
# [45 49 50]
# [45 49 50]
# [31 35 36]
# [29 33 34]
# [29 33 34]
# [33 37 38]
# [31 35 36]
# [30 34 35]
# [35 39 40]
# [30 34 35]
# [25 29 30]
# [36 40 41]
# [31 35 36]
# [27 31 32]
# [37 41 42]
# [25 29 30]
# [42 46 47]
# [30 34 35]
# [29 33 34]
# [33 37 38]
# [33 37 38]
# [28 32 33]
# [22 26 27]
# [25 29 30]
# [27 31 32]
# [35 39 40]
# [27 31 32]
# [36 40 41]
# [43 47 48]
# [39 43 44]
# [37 41 42]
# [32 36 37]
# ...

# %%
for i in range(RGB_imgC3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024 colum
                if 1849<i<2101 and 1799<j<2001:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง  1894-2101ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(RGB_imgC3[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [39 43 44]
# [41 45 46]
# [49 53 54]
# [51 55 56]
# [44 48 49]
# [44 48 49]
# [45 49 50]
# [44 48 49]
# [44 48 49]
# [53 57 58]
# [38 42 43]
# [31 35 36]
# [45 49 50]
# [34 38 39]
# [35 39 40]
# [41 45 46]
# [42 46 47]
# [46 50 51]
# [50 54 55]
# [39 43 44]
# [39 43 44]
# [42 46 47]
# [46 50 51]
# [53 57 58]
# [43 47 48]
# [48 52 53]
# [33 37 38]
# [28 32 33]
# [46 50 51]
# [41 45 46]
# [38 42 43]
# [33 37 38]
# [44 48 49]
# [38 42 43]
# [41 45 46]
# [39 43 44]
# [38 42 43]
# [41 45 46]
# [41 45 46]
# [35 39 40]
# [35 39 40]
# [33 37 38]
# [46 50 51]
# [44 48 49]
# [45 49 50]
# [51 55 56]
# [53 57 58]
# [36 40 41]
# [49 53 54]
# [38 42 43]
# [30 34 35]
# [36 40 41]
# [42 46 47]
# [37 41 42]
# [44 48 49]
# [36 40 41]
# [35 39 40]
# [32 36 37]
# [47 51 52]
# [41 45 46]
# [38 42 43]
# [35 39 40]
# [38 42 43]
# [39 43 44]
# [43 47 48]
# [37 41 42]
# [35 39 40]
# [31 35 36]
# [47 51 52]
# [35 39 40]
# [34 38 39]
# [34 38 39]
# ...

# %%
for i in range(RGB_imgC4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgC4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024 colum
                if 1849<i<2101 and 1799<j<2001:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1894-2101 ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(RGB_imgC4[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [45 49 50]
# [40 44 45]
# [39 43 44]
# [38 42 43]
# [47 51 52]
# [50 54 55]
# [40 44 45]
# [49 53 54]
# [43 47 48]
# [33 37 38]
# [38 42 43]
# [47 51 52]
# [48 52 53]
# [44 48 49]
# [39 43 44]
# [34 38 39]
# [33 37 38]
# [42 46 47]
# [44 48 49]
# [33 37 38]
# [35 39 40]
# [44 48 49]
# [40 44 45]
# [41 45 46]
# [42 46 47]
# [43 47 48]
# [33 37 38]
# [35 39 40]
# [41 45 46]
# [37 41 42]
# [32 36 37]
# [41 45 46]
# [42 46 47]
# [48 52 53]
# [40 44 45]
# [33 37 38]
# [45 49 50]
# [40 44 45]
# [43 47 48]
# [38 42 43]
# [44 48 49]
# [48 52 53]
# [37 41 42]
# [29 33 34]
# [32 36 37]
# [39 43 44]
# [43 47 48]
# [37 41 42]
# [45 49 50]
# [40 44 45]
# [40 44 45]
# [42 46 47]
# [38 42 43]
# [40 44 45]
# [41 45 46]
# [39 43 44]
# [40 44 45]
# [35 39 40]
# [36 40 41]
# [38 42 43]
# [35 39 40]
# [35 39 40]
# [36 40 41]
# [33 37 38]
# [29 33 34]
# [37 41 42]
# [35 39 40]
# [40 44 45]
# [41 45 46]
# [33 37 38]
# [33 37 38]
# [41 45 46]
# ...

# %%
for i in range(RGB_imgD2 .shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(RGB_imgD2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024colum เช่น แถวที่ 1 เข้ามาให้รันครบ 400 colum
                if 1849<i<2101 and 1799<j<2001:#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1849-2101 และ ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(RGB_imgD2 [i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [38 42 43]
# [42 46 47]
# [36 40 41]
# [30 34 35]
# [32 36 37]
# [41 45 46]
# [44 48 49]
# [40 44 45]
# [36 40 41]
# [33 37 38]
# [31 35 36]
# [38 42 43]
# [38 42 43]
# [30 34 35]
# [34 38 39]
# [32 36 37]
# [34 38 39]
# [34 38 39]
# [38 42 43]
# [36 40 41]
# [34 38 39]
# [30 34 35]
# [36 40 41]
# [24 28 29]
# [33 37 38]
# [31 35 36]
# [28 32 33]
# [27 31 32]
# [29 33 34]
# [38 42 43]
# [40 44 45]
# [38 42 43]
# [41 45 46]
# [31 35 36]
# [31 35 36]
# [34 38 39]
# [33 37 38]
# [31 35 36]
# [35 39 40]
# [36 40 41]
# [35 39 40]
# [41 45 46]
# [31 35 36]
# [34 38 39]
# [39 43 44]
# [38 42 43]
# [31 35 36]
# [40 44 45]
# [36 40 41]
# [39 43 44]
# [35 39 40]
# [40 44 45]
# [40 44 45]
# [38 42 43]
# [28 32 33]
# [35 39 40]
# [32 36 37]
# [36 40 41]
# [36 40 41]
# [37 41 40]
# [28 32 31]
# [30 34 33]
# [34 38 37]
# [34 38 39]
# [27 31 32]
# [23 27 28]
# [24 28 29]
# [32 36 37]
# [35 39 40]
# [27 31 32]
# [26 30 31]
# [27 31 32]
# ...

# %% [markdown]
# #วาดกรอบสี่เหลี่ยม

# %%
RGB_imgA4.shape
# Out:
# (3024, 4032, 3)

# %%
img01= cv2.rectangle(RGB_imgA4,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgA4)#โชว์รูป

# %%
img02= cv2.rectangle(RGB_imgA3_5,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgA3_5)#โชว์รูป

# %%
img03= cv2.rectangle(RGB_imgB2,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgB2)#โชว์รูป

# %%
img04= cv2.rectangle(RGB_imgC1,(1850,2000),(2100,1800),(255,0,0),10)#วาดสี่เหลี่ยม
plt.imshow(RGB_imgC1)#โชว์รูป

# %%
img05= cv2.rectangle(RGB_imgC2,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgC2)#โชว์รูป

# %%
img06= cv2.rectangle(RGB_imgC3,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgC3)#โชว์รูป

# %%
img07= cv2.rectangle(RGB_imgC4,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgC4)#โชว์รูป

# %%
img08= cv2.rectangle(RGB_imgD2,(1850,2000),(2100,1800),(255,0,0),10) #วาดสี่เหลี่ยม
plt.imshow(RGB_imgD2)#โชว์รูป
